# %% [markdown]
# # Limpieza de datos
# ***

# %% [markdown]
# ### Librerías

# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")#ignorar advertencias

# %% [markdown]
# ### Carga de datos

# %%
df = pd.read_csv("../Data/df_original_250519.csv")
df
# Out:
#           id   age          job  marital  education default  balance housing  \
# 0          1  59.0       admin.  married  secondary      no     2343     yes
# 1          2  59.0       admin.  married  secondary      no     2343     yes
# 2          3  56.0       admin.  married  secondary      no       45      no
# 3          4  41.0   technician  married  secondary      no     1270     yes
# 4          5  55.0     services  married  secondary      no     2476     yes
# ...      ...   ...          ...      ...        ...     ...      ...     ...
# 16168  19679  47.0  blue-collar  married  secondary      no     1230     yes
# 16169   7066  31.0   management  married   tertiary      no      927      no
# 16170   9824  37.0   management   single   tertiary      no        0      no
# 16171  18110  63.0      retired  married  secondary      no     2896      no
# 16172  20260  38.0  blue-collar  married    primary      no     4592     yes
#
#       loan    contact  day month  duration  campaign  pdays  previous  \
# 0       no    unknown    5   may      1042         1     -1         0
# 1       no    unknown    5   may      1042         1     -1         0
# 2       no    unknown    5   may      1467         1     -1         0
# 3       no    unknown    5   may      1389         1     -1         0
# 4       no    unknown    5   may       579         1     -1         0
# ...    ...        ...  ...   ...       ...       ...    ...       ...
# 16168   no  telephone   12   nov       378         1     -1         0
# 16169   no   cellular   18   aug       100         4     -1         0
# 16170   no   cellular    7   jul       643         3     -1         0
# 16171   no   cellular    1   jul       304         1    119         2
# 16172   no   cellular   12   may       360         1     -1         0
#
#       poutcome deposit
# 0      unknown     yes
# 1      unknown     yes
# 2      unknown     yes
# 3      unknown     yes
# 4      unknown     yes
# ...        ...     ...
# 16168  unknown     yes
# 16169  unknown      no
# 16170  unknown      no
# 16171  success     yes
# 16172  unknown      no
#
# [16173 rows x 18 columns]

# %% [markdown]
# ### Duplicados exactos

# %%
duplicados = df[df.duplicated()]
print(f"Filas duplicadas exactas: {len(duplicados)}")
duplicados
# Out:
# Filas duplicadas exactas: 10
#           id   age          job   marital  education default  balance housing  \
# 16163   9609  26.0  blue-collar   married  secondary      no      895     yes
# 16164   1027  37.0   technician  divorced  secondary      no     3068     yes
# 16165  18834  45.0   management  divorced   tertiary      no        1      no
# 16166   3028  66.0    housemaid   married    primary      no     1230      no
# 16167   4943  49.0   management   married  secondary      no     1623     yes
# 16168  19679  47.0  blue-collar   married  secondary      no     1230     yes
# 16169   7066  31.0   management   married   tertiary      no      927      no
# 16170   9824  37.0   management    single   tertiary      no        0      no
# 16171  18110  63.0      retired   married  secondary      no     2896      no
# 16172  20260  38.0  blue-collar   married    primary      no     4592     yes
#
#       loan    contact  day month  duration  campaign  pdays  previous  \
# 16163   no   cellular    4   feb       820         3     -1         0
# 16164  yes   cellular   20   nov       370         2    195         1
# 16165   no   cellular    6   aug       490         2     -1         0
# 16166   no   cellular   17   dec       726         3     -1         0
# 16167   no   cellular   19   nov      1081         2     -1         0
# 16168   no  telephone   12   nov       378         1     -1         0
# 16169   no   cellular   18   aug       100         4     -1         0
# 16170   no   cellular    7   jul       643         3     -1         0
# 16171   no   cellular    1   jul       304         1    119         2
# 16172   no   cellular   12   may       360         1     -1         0
#
#       poutcome deposit
# 16163  unknown      no
# 16164    other     yes
# 16165  unknown     yes
# 16166  unknown     yes
# 16167  unknown     yes
# 16168  unknown     yes
# 16169  unknown      no
# 16170  unknown      no
# 16171  success     yes
# 16172  unknown      no

# %% [markdown]
# Se han detectado 10 filas duplicadas exactas, las eliminamos por que no aportan informacion nueva al analisis y pueden sesgar resultados

# %%
# Eliminar duplicados exactos
df = df.drop_duplicates()

# Confirmar que se han eliminado
print(df.shape)
# Out:
# (16163, 18)

# %% [markdown]
# ### Valores nulos

# %%
df.isnull().sum()
# Out:
# id            0
# age          13
# job           0
# marital       9
# education    10
# default       0
# balance       0
# housing      20
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# deposit       0
# dtype: int64

# %% [markdown]
# Tratamiento de nulos tras acuerdo grupal
# - age --> media age
# - marital --> moda marital
# - education --> unknown
# - housing --> moda housing

# %%
print(df['age'].mean())             # 41.17295792079208
print(df['marital'].mode())         # 0    married --> Solo hay una moda
print(df['education'].unique())     # ['secondary' 'tertiary' 'primary' 'unknown' nan]
print(df['housing'].mode())         # 0    no --> Solo hay una moda
# Out:
# 41.171269349845204
# 0    married
# Name: marital, dtype: object
# ['secondary' 'tertiary' 'primary' 'unknown' nan]
# 0    no
# Name: housing, dtype: object

# %%
# Rellenar valores nulos
df['age'].fillna(df['age'].mean(), inplace=True)
df['marital'].fillna(df['marital'].mode()[0], inplace=True)
df['education'].fillna('unknown', inplace=True)
df['housing'].fillna(df['housing'].mode()[0], inplace=True)

# %%
# Comprobar
df.isnull().sum()
# Out:
# id           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %% [markdown]
# ### Convertir columnas booleanas

# %%
# Detectar columnas con solo 'yes' y 'no'
for col in df.columns:
    unique_vals = df[col].dropna().unique()
    if set(unique_vals).issubset({'yes', 'no'}):
        print(f"La columna '{col}' contiene solo 'yes' y 'no'")
# Out:
# La columna 'default' contiene solo 'yes' y 'no'
# La columna 'housing' contiene solo 'yes' y 'no'
# La columna 'loan' contiene solo 'yes' y 'no'
# La columna 'deposit' contiene solo 'yes' y 'no'

# %%
# Convertir columnas binarias 'yes'/'no' a booleanas
bool_columns = ['default', 'housing', 'loan', 'deposit']
for col in bool_columns:
    df[col] = df[col].map({'yes': True, 'no': False})
print(df.dtypes)
# Out:
# id             int64
# age          float64
# job           object
# marital       object
# education     object
# default         bool
# balance        int64
# housing         bool
# loan            bool
# contact       object
# day            int64
# month         object
# duration       int64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# deposit         bool
# dtype: object

# %% [markdown]
# ### Corrección columna `age`

# %%
# Convertir 'age' a entero 
df['age'] = pd.to_numeric(df['age'], errors='coerce').fillna(0).astype(int)
print(df.dtypes)
# Out:
# id            int64
# age           int64
# job          object
# marital      object
# education    object
# default        bool
# balance       int64
# housing        bool
# loan           bool
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# deposit        bool
# dtype: object

# %% [markdown]
# ### Corrección columna `month`

# %%
# Asegurar que 'month' tenga solo la primera letra en mayúscula
df['month'] = df['month'].str.strip().str.lower().str.capitalize()
df
# Out:
#           id  age          job   marital  education  default  balance  \
# 0          1   59       admin.   married  secondary    False     2343
# 1          2   59       admin.   married  secondary    False     2343
# 2          3   56       admin.   married  secondary    False       45
# 3          4   41   technician   married  secondary    False     1270
# 4          5   55     services   married  secondary    False     2476
# ...      ...  ...          ...       ...        ...      ...      ...
# 16158  21379   82    housemaid  divorced    primary    False     1381
# 16159  21380   35  blue-collar   married    unknown    False     1084
# 16160  21381   33   technician   married  secondary     True       72
# 16161  21382   23      student    single  secondary    False      480
# 16162  21383   42       admin.    single  secondary    False      243
#
#        housing   loan   contact  day month  duration  campaign  pdays  \
# 0         True  False   unknown    5   May      1042         1     -1
# 1         True  False   unknown    5   May      1042         1     -1
# 2        False  False   unknown    5   May      1467         1     -1
# 3         True  False   unknown    5   May      1389         1     -1
# 4         True  False   unknown    5   May       579         1     -1
# ...        ...    ...       ...  ...   ...       ...       ...    ...
# 16158    False  False  cellular   28   Jan        86         3     93
# 16159     True  False  cellular   10   Jul      1019         1     -1
# 16160     True  False   unknown    6   May       623         1     -1
# 16161    False  False  cellular    9   Feb       742         2    182
# 16162     True  False   unknown   14   May        46         5     -1
#
#        previous poutcome  deposit
# 0             0  unknown     True
# 1             0  unknown     True
# 2             0  unknown     True
# 3             0  unknown     True
# 4             0  unknown     True
# ...         ...      ...      ...
# 16158         1  failure    False
# 16159         0  unknown    False
# 16160         0  unknown    False
# 16161         1  failure     True
# 16162         0  unknown    False
#
# [16163 rows x 18 columns]

# %% [markdown]
# ### Crear columna `date`

# %%
# Crear columna 'date' combinando 'day' y 'month' (asumiendo año 2024)
df['date'] = pd.to_datetime(
    df['day'].astype(str) + '-' + df['month'] + '-2024',
    dayfirst=True
)
df
# Out:
#           id  age          job   marital  education  default  balance  \
# 0          1   59       admin.   married  secondary    False     2343
# 1          2   59       admin.   married  secondary    False     2343
# 2          3   56       admin.   married  secondary    False       45
# 3          4   41   technician   married  secondary    False     1270
# 4          5   55     services   married  secondary    False     2476
# ...      ...  ...          ...       ...        ...      ...      ...
# 16158  21379   82    housemaid  divorced    primary    False     1381
# 16159  21380   35  blue-collar   married    unknown    False     1084
# 16160  21381   33   technician   married  secondary     True       72
# 16161  21382   23      student    single  secondary    False      480
# 16162  21383   42       admin.    single  secondary    False      243
#
#        housing   loan   contact  day month  duration  campaign  pdays  \
# 0         True  False   unknown    5   May      1042         1     -1
# 1         True  False   unknown    5   May      1042         1     -1
# 2        False  False   unknown    5   May      1467         1     -1
# 3         True  False   unknown    5   May      1389         1     -1
# 4         True  False   unknown    5   May       579         1     -1
# ...        ...    ...       ...  ...   ...       ...       ...    ...
# 16158    False  False  cellular   28   Jan        86         3     93
# 16159     True  False  cellular   10   Jul      1019         1     -1
# 16160     True  False   unknown    6   May       623         1     -1
# 16161    False  False  cellular    9   Feb       742         2    182
# 16162     True  False   unknown   14   May        46         5     -1
#
#        previous poutcome  deposit       date
# 0             0  unknown     True 2024-05-05
# 1             0  unknown     True 2024-05-05
# 2             0  unknown     True 2024-05-05
# 3             0  unknown     True 2024-05-05
# 4             0  unknown     True 2024-05-05
# ...         ...      ...      ...        ...
# 16158         1  failure    False 2024-01-28
# 16159         0  unknown    False 2024-07-10
# 16160         0  unknown    False 2024-05-06
# 16161         1  failure     True 2024-02-09
# 16162         0  unknown    False 2024-05-14
#
# [16163 rows x 19 columns]

# %% [markdown]
# ### Guardar el DataFrame limpio

# %%
df.to_csv("../Data/df_cleaned_250519.csv")
