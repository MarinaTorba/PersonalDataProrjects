# %% [markdown]
# # SPRINT N°3
# * Fecha de inicio: 09/12/2024
# * Fecha de presentación: 12/12/2024

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# ### LIBRERÍAS

# %%
import pymysql
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### CONEXIÓN

# %%
EquipC = pymysql.connect(
  host= "212.227.90.6",
  user="EquipoC",
  password="E1q2u3i4p5oC",
  database="EquipC"
)
print(EquipC)
# Out:
# <pymysql.connections.Connection object at 0x00000133668B8910>

# %%
mycursor = EquipC.cursor()
mycursor.execute("SELECT DATABASE()")
current_db = mycursor.fetchone()
print("Base de datos actual:", current_db)
mycursor.execute("SHOW TABLES")
# Out:
# Base de datos actual: ('EquipC',)
# 4

# %%
mycursor.execute("SHOW TABLES")
for x in mycursor:
    print(x)
# Out:
# ('BANK_marketing',)
# ('BANK_marketing021224',)
# ('BANK_marketing091224',)
# ('vista_finanzas',)

# %%
#bbdd SPRINT 1
BANK_marketing = 'SELECT * FROM BANK_marketing'
df_BANK_marketing = pd.read_sql(BANK_marketing, EquipC)

#bbdd SPRINT 3
BANK_marketing021224 = 'SELECT * FROM BANK_marketing021224'
df_BANK_marketing021224 = pd.read_sql(BANK_marketing021224, EquipC)

#bbdd SPRINT 3
BANK_marketing091224 = 'SELECT * FROM BANK_marketing091224'
df_BANK_marketing091224 = pd.read_sql(BANK_marketing091224, EquipC)
# Out:
# C:\Users\Federico Labate\AppData\Local\Temp\ipykernel_16684\2328067774.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_BANK_marketing = pd.read_sql(BANK_marketing, EquipC)
# C:\Users\Federico Labate\AppData\Local\Temp\ipykernel_16684\2328067774.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_BANK_marketing021224 = pd.read_sql(BANK_marketing021224, EquipC)
# C:\Users\Federico Labate\AppData\Local\Temp\ipykernel_16684\2328067774.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_BANK_marketing091224 = pd.read_sql(BANK_marketing091224, EquipC)

# %% [markdown]
# ### DATAFRAME

# %% [markdown]
# #### SPRINT N°1

# %%
df_BANK_marketing
# Out:
#           id   age          job  marital  education default  balance housing  \
# 0          1  59.0       admin.  married  secondary      no     2343     yes
# 1          2  59.0       admin.  married  secondary      no     2343     yes
# 2          3  56.0       admin.  married  secondary      no       45      no
# 3          4  41.0   technician  married  secondary      no     1270     yes
# 4          5  55.0     services  married  secondary      no     2476     yes
# ...      ...   ...          ...      ...        ...     ...      ...     ...
# 11158  11159  33.0  blue-collar   single    primary      no        1     yes
# 11159  11160  39.0     services  married  secondary      no      733      no
# 11160  11161  32.0   technician   single  secondary      no       29      no
# 11161  11162  43.0   technician  married  secondary      no        0      no
# 11162  11163  34.0   technician  married  secondary      no        0      no
#
#       loan   contact  day month  duration  campaign  pdays  previous poutcome  \
# 0       no   unknown    5   may      1042         1     -1         0  unknown
# 1       no   unknown    5   may      1042         1     -1         0  unknown
# 2       no   unknown    5   may      1467         1     -1         0  unknown
# 3       no   unknown    5   may      1389         1     -1         0  unknown
# 4       no   unknown    5   may       579         1     -1         0  unknown
# ...    ...       ...  ...   ...       ...       ...    ...       ...      ...
# 11158   no  cellular   20   apr       257         1     -1         0  unknown
# 11159   no   unknown   16   jun        83         4     -1         0  unknown
# 11160   no  cellular   19   aug       156         2     -1         0  unknown
# 11161  yes  cellular    8   may         9         2    172         5  failure
# 11162   no  cellular    9   jul       628         1     -1         0  unknown
#
#       deposit
# 0         yes
# 1         yes
# 2         yes
# 3         yes
# 4         yes
# ...       ...
# 11158      no
# 11159      no
# 11160      no
# 11161      no
# 11162      no
#
# [11163 rows x 18 columns]

# %% [markdown]
# #### SPRINT N°2

# %%
df_BANK_marketing021224
# Out:
#           id   age            job   marital  education default  balance  \
# 0          1  59.0         admin.   married  secondary      no     2343
# 1          2  59.0         admin.   married  secondary      no     2343
# 2          3  56.0         admin.   married  secondary      no       45
# 3          4  41.0     technician   married  secondary      no     1270
# 4          5  55.0       services   married  secondary      no     2476
# ...      ...   ...            ...       ...        ...     ...      ...
# 16168   6661  46.0       services  divorced    unknown      no     3390
# 16169  17819  45.0     unemployed  divorced    primary     yes       11
# 16170   2487  58.0  self-employed   married    primary      no     1013
# 16171    523  58.0        retired   married    unknown      no     9004
# 16172   2362  42.0   entrepreneur   married  secondary      no     2959
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# 0         yes   no    unknown    5   may      1042         1     -1         0
# 1         yes   no    unknown    5   may      1042         1     -1         0
# 2          no   no    unknown    5   may      1467         1     -1         0
# 3         yes   no    unknown    5   may      1389         1     -1         0
# 4         yes   no    unknown    5   may       579         1     -1         0
# ...       ...  ...        ...  ...   ...       ...       ...    ...       ...
# 16168      no   no    unknown   20   jun       152         3     -1         0
# 16169      no   no   cellular   13   aug       489         5     -1         0
# 16170     yes   no   cellular   11   aug       206         1    461         1
# 16171      no   no   cellular   21   jul       891         4     -1         0
# 16172     yes   no  telephone    2   jul       711         1    342         1
#
#       poutcome deposit
# 0      unknown     yes
# 1      unknown     yes
# 2      unknown     yes
# 3      unknown     yes
# 4      unknown     yes
# ...        ...     ...
# 16168  unknown      no
# 16169  unknown     yes
# 16170  failure     yes
# 16171  unknown     yes
# 16172  failure     yes
#
# [16173 rows x 18 columns]

# %% [markdown]
# #### SPRINT Nº3

# %%
df_BANK_marketing091224
# Out:
#           id   age          job  marital  education default  balance housing  \
# 0          1  59.0       admin.  married  secondary      no     2343     yes
# 1          2  59.0       admin.  married  secondary      no     2343     yes
# 2          3  56.0       admin.  married  secondary      no       45      no
# 3          4  41.0   technician  married  secondary      no     1270     yes
# 4          5  55.0     services  married  secondary      no     2476     yes
# ...      ...   ...          ...      ...        ...     ...      ...     ...
# 26183   7969  47.0  blue-collar  married  secondary      no     -337     yes
# 26184  21371  40.0       admin.  married  secondary      no     1327     yes
# 26185  18263  58.0   unemployed   single   tertiary      no     2094      no
# 26186   4466  40.0    housemaid   single   tertiary      no     7441      no
# 26187  19515  42.0  blue-collar  married    primary      no     2003     yes
#
#       loan   contact  day month  duration  campaign  pdays  previous poutcome  \
# 0       no   unknown    5   may      1042         1     -1         0  unknown
# 1       no   unknown    5   may      1042         1     -1         0  unknown
# 2       no   unknown    5   may      1467         1     -1         0  unknown
# 3       no   unknown    5   may      1389         1     -1         0  unknown
# 4       no   unknown    5   may       579         1     -1         0  unknown
# ...    ...       ...  ...   ...       ...       ...    ...       ...      ...
# 26183  yes  cellular   12   may       366         1     -1         0  unknown
# 26184  yes   unknown   26   may        76         2     -1         0  unknown
# 26185   no  cellular    1   jun       161         2     -1         0  unknown
# 26186   no  cellular   31   jul      1461         6     -1         0  unknown
# 26187   no  cellular   17   apr       177         3     -1         0  unknown
#
#       deposit
# 0         yes
# 1         yes
# 2         yes
# 3         yes
# 4         yes
# ...       ...
# 26183      no
# 26184      no
# 26185      no
# 26186     yes
# 26187      no
#
# [26188 rows x 18 columns]

# %% [markdown]
# ##### REGISTROS NUEVOS

# %%
diff_count = len(df_BANK_marketing091224) -  len(df_BANK_marketing021224)
print(f"Registros nuevos: {diff_count}")
# Out:
# Registros nuevos: 10015

# %% [markdown]
# ### RENOMBRO DATRAFAME PARA APROVECHAR EL SCRIPT

# %%
S3_df_BANK_marketing = df_BANK_marketing091224

# %% [markdown]
# ### RENOMBRAR COLUMNAS

# %% [markdown]
# #### deafult -> is_in_deafult

# %%
S3_df_BANK_marketing.rename(columns={'default': 'is_in_default'}, inplace=True)
S3_df_BANK_marketing
# Out:
#           id   age          job  marital  education is_in_default  balance  \
# 0          1  59.0       admin.  married  secondary            no     2343
# 1          2  59.0       admin.  married  secondary            no     2343
# 2          3  56.0       admin.  married  secondary            no       45
# 3          4  41.0   technician  married  secondary            no     1270
# 4          5  55.0     services  married  secondary            no     2476
# ...      ...   ...          ...      ...        ...           ...      ...
# 26183   7969  47.0  blue-collar  married  secondary            no     -337
# 26184  21371  40.0       admin.  married  secondary            no     1327
# 26185  18263  58.0   unemployed   single   tertiary            no     2094
# 26186   4466  40.0    housemaid   single   tertiary            no     7441
# 26187  19515  42.0  blue-collar  married    primary            no     2003
#
#       housing loan   contact  day month  duration  campaign  pdays  previous  \
# 0         yes   no   unknown    5   may      1042         1     -1         0
# 1         yes   no   unknown    5   may      1042         1     -1         0
# 2          no   no   unknown    5   may      1467         1     -1         0
# 3         yes   no   unknown    5   may      1389         1     -1         0
# 4         yes   no   unknown    5   may       579         1     -1         0
# ...       ...  ...       ...  ...   ...       ...       ...    ...       ...
# 26183     yes  yes  cellular   12   may       366         1     -1         0
# 26184     yes  yes   unknown   26   may        76         2     -1         0
# 26185      no   no  cellular    1   jun       161         2     -1         0
# 26186      no   no  cellular   31   jul      1461         6     -1         0
# 26187     yes   no  cellular   17   apr       177         3     -1         0
#
#       poutcome deposit
# 0      unknown     yes
# 1      unknown     yes
# 2      unknown     yes
# 3      unknown     yes
# 4      unknown     yes
# ...        ...     ...
# 26183  unknown      no
# 26184  unknown      no
# 26185  unknown      no
# 26186  unknown     yes
# 26187  unknown      no
#
# [26188 rows x 18 columns]

# %% [markdown]
# ### RENOMBRAR REGISTROS

# %% [markdown]
# #### yes = 1, no = 0

# %%
S3_df_BANK_marketing = S3_df_BANK_marketing.replace({'yes': 1, 'no': 0})
S3_df_BANK_marketing
# Out:
# C:\Users\Federico Labate\AppData\Local\Temp\ipykernel_16684\2106408135.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   S3_df_BANK_marketing = S3_df_BANK_marketing.replace({'yes': 1, 'no': 0})
#           id   age          job  marital  education  is_in_default  balance  \
# 0          1  59.0       admin.  married  secondary            0.0     2343
# 1          2  59.0       admin.  married  secondary            0.0     2343
# 2          3  56.0       admin.  married  secondary            0.0       45
# 3          4  41.0   technician  married  secondary            0.0     1270
# 4          5  55.0     services  married  secondary            0.0     2476
# ...      ...   ...          ...      ...        ...            ...      ...
# 26183   7969  47.0  blue-collar  married  secondary            0.0     -337
# 26184  21371  40.0       admin.  married  secondary            0.0     1327
# 26185  18263  58.0   unemployed   single   tertiary            0.0     2094
# 26186   4466  40.0    housemaid   single   tertiary            0.0     7441
# 26187  19515  42.0  blue-collar  married    primary            0.0     2003
#
#        housing  loan   contact  day month  duration  campaign  pdays  \
# 0          1.0     0   unknown    5   may      1042         1     -1
# 1          1.0     0   unknown    5   may      1042         1     -1
# 2          0.0     0   unknown    5   may      1467         1     -1
# 3          1.0     0   unknown    5   may      1389         1     -1
# 4          1.0     0   unknown    5   may       579         1     -1
# ...        ...   ...       ...  ...   ...       ...       ...    ...
# 26183      1.0     1  cellular   12   may       366         1     -1
# 26184      1.0     1   unknown   26   may        76         2     -1
# 26185      0.0     0  cellular    1   jun       161         2     -1
# 26186      0.0     0  cellular   31   jul      1461         6     -1
# 26187      1.0     0  cellular   17   apr       177         3     -1
#
#        previous poutcome  deposit
# 0             0  unknown        1
# 1             0  unknown        1
# 2             0  unknown        1
# 3             0  unknown        1
# 4             0  unknown        1
# ...         ...      ...      ...
# 26183         0  unknown        0
# 26184         0  unknown        0
# 26185         0  unknown        0
# 26186         0  unknown        1
# 26187         0  unknown        0
#
# [26188 rows x 18 columns]

# %% [markdown]
# ### RESOLVER ESPACIOS EN BLANCO

# %%
S3_df_BANK_marketing = S3_df_BANK_marketing.replace({' ':''})
S3_df_BANK_marketing
# Out:
#           id   age          job  marital  education  is_in_default  balance  \
# 0          1  59.0       admin.  married  secondary            0.0     2343
# 1          2  59.0       admin.  married  secondary            0.0     2343
# 2          3  56.0       admin.  married  secondary            0.0       45
# 3          4  41.0   technician  married  secondary            0.0     1270
# 4          5  55.0     services  married  secondary            0.0     2476
# ...      ...   ...          ...      ...        ...            ...      ...
# 26183   7969  47.0  blue-collar  married  secondary            0.0     -337
# 26184  21371  40.0       admin.  married  secondary            0.0     1327
# 26185  18263  58.0   unemployed   single   tertiary            0.0     2094
# 26186   4466  40.0    housemaid   single   tertiary            0.0     7441
# 26187  19515  42.0  blue-collar  married    primary            0.0     2003
#
#        housing  loan   contact  day month  duration  campaign  pdays  \
# 0          1.0     0   unknown    5   may      1042         1     -1
# 1          1.0     0   unknown    5   may      1042         1     -1
# 2          0.0     0   unknown    5   may      1467         1     -1
# 3          1.0     0   unknown    5   may      1389         1     -1
# 4          1.0     0   unknown    5   may       579         1     -1
# ...        ...   ...       ...  ...   ...       ...       ...    ...
# 26183      1.0     1  cellular   12   may       366         1     -1
# 26184      1.0     1   unknown   26   may        76         2     -1
# 26185      0.0     0  cellular    1   jun       161         2     -1
# 26186      0.0     0  cellular   31   jul      1461         6     -1
# 26187      1.0     0  cellular   17   apr       177         3     -1
#
#        previous poutcome  deposit
# 0             0  unknown        1
# 1             0  unknown        1
# 2             0  unknown        1
# 3             0  unknown        1
# 4             0  unknown        1
# ...         ...      ...      ...
# 26183         0  unknown        0
# 26184         0  unknown        0
# 26185         0  unknown        0
# 26186         0  unknown        1
# 26187         0  unknown        0
#
# [26188 rows x 18 columns]

# %% [markdown]
# ### DUPLICADOS

# %%
S3_df_BANK_marketing.duplicated().sum()
# Out:
# np.int64(9)

# %%
#Registros duplicados
duplicated_rows = S3_df_BANK_marketing[S3_df_BANK_marketing.duplicated()]
print("Registros duplicados:")
duplicated_rows
# Out:
# Registros duplicados:
#           id   age          job  marital  education  is_in_default  balance  \
# 26173   6091  54.0       admin.  married  secondary            0.0        0
# 26174   5445  24.0     services   single  secondary            0.0     1299
# 26175   5489  43.0      unknown  married    unknown            0.0     1517
# 26176   9316  48.0    housemaid   single  secondary            0.0       71
# 26178   4624  51.0       admin.  married   tertiary            0.0        0
# 26180  10045  31.0     services   single  secondary            0.0      658
# 26182   1476  30.0   unemployed  married   tertiary            0.0      330
# 26183   7969  47.0  blue-collar  married  secondary            0.0     -337
# 26186   4466  40.0    housemaid   single   tertiary            0.0     7441
#
#        housing  loan   contact  day month  duration  campaign  pdays  \
# 26173      1.0     1  cellular   23   jul       117         1     -1
# 26174      1.0     1  cellular   18   may       113         2     -1
# 26175      0.0     0   unknown   20   jun        45         1     -1
# 26176      0.0     0  cellular   28   aug        97         3     -1
# 26178      1.0     1  cellular    8   mar       124         2     -1
# 26180      0.0     0  cellular   22   may       100         1     -1
# 26182      0.0     0  cellular   14   apr       111         1     -1
# 26183      1.0     1  cellular   12   may       366         1     -1
# 26186      0.0     0  cellular   31   jul      1461         6     -1
#
#        previous poutcome  deposit
# 26173         0  unknown        0
# 26174         0  unknown        0
# 26175         0  unknown        0
# 26176         0  unknown        0
# 26178         0  unknown        1
# 26180         0  unknown        0
# 26182         0  unknown        1
# 26183         0  unknown        0
# 26186         0  unknown        1

# %% [markdown]
# #### RESOLUCIÓN DE DUPLICADOS

# %%
S3_df_BANK_marketing = S3_df_BANK_marketing.drop_duplicates()

# %%
duplicated_ids = S3_df_BANK_marketing[S3_df_BANK_marketing.duplicated(subset='id', keep=False)]['id'].unique()
duplicated_ids
# Out:
# array([17721, 17926, 18263, 19515, 20490, 21371])

# %% [markdown]
# Al comprobar si se habían borrado los duplicados, nos damos cuenta que hay ID's que no se han borrado, esto significa que el contenido de estas ID's no está repetido, por lo que resolvemos el problema cambiandoles la ID por una nueva para seguir manteniedo los datos.

# %%
duplicated_ids = S3_df_BANK_marketing[S3_df_BANK_marketing.duplicated(subset='id', keep=False)]['id'].unique()
duplicated_ids
# Out:
# array([17721, 17926, 18263, 19515, 20490, 21371])

# %%
ids_to_filter = [17721, 17926, 18263, 19515, 20490, 21371]

# Filtrar filas con las IDs especificadas
filtered_rows = S3_df_BANK_marketing[S3_df_BANK_marketing['id'].isin(ids_to_filter)]
print(filtered_rows)
# Out:
#           id   age           job  marital  education  is_in_default  balance  \
# 17510  17721  31.0  entrepreneur  married  secondary            0.0       15
# 17715  17926  37.0    management  married   tertiary            0.0     -666
# 18052  18263  41.0    management  married   tertiary            0.0        0
# 19304  19515  57.0       retired  married    primary            0.0     9367
# 20279  20490  44.0    technician  married   tertiary            0.0      964
# 21160  21371  42.0     housemaid  married    primary            1.0       16
# 26177  17926  37.0      services   single  secondary            0.0      278
# 26179  17721  60.0       retired  married    primary            0.0       71
# 26181  20490  47.0   blue-collar  married  secondary            0.0      802
# 26184  21371  40.0        admin.  married  secondary            0.0     1327
# 26185  18263  58.0    unemployed   single   tertiary            0.0     2094
# 26187  19515  42.0   blue-collar  married    primary            0.0     2003
#
#        housing  loan   contact  day month  duration  campaign  pdays  \
# 17510      0.0     1  cellular   29   jan       190         2     -1
# 17715      1.0     0  cellular   18   nov       204         2     -1
# 18052      1.0     0  cellular   18   nov       897         3     -1
# 19304      0.0     0  cellular   11   feb       981         1     90
# 20279      0.0     0  cellular   29   jul       158         2     -1
# 21160      0.0     0   unknown   11   jun        79         1     -1
# 26177      1.0     0   unknown    3   jun      1045         3     -1
# 26179      0.0     0  cellular   10   jul       121         3     -1
# 26181      1.0     1  cellular   12   may       289         2     -1
# 26184      1.0     1   unknown   26   may        76         2     -1
# 26185      0.0     0  cellular    1   jun       161         2     -1
# 26187      1.0     0  cellular   17   apr       177         3     -1
#
#        previous poutcome  deposit
# 17510         0  unknown        0
# 17715         0  unknown        0
# 18052         0  unknown        1
# 19304         6  success        1
# 20279         0  unknown        0
# 21160         0  unknown        0
# 26177         0  unknown        1
# 26179         0  unknown        0
# 26181         0  unknown        1
# 26184         0  unknown        0
# 26185         0  unknown        0
# 26187         0  unknown        0

# %% [markdown]
# #### RESOLUCIÓN DE ID's DUPLICADOS

# %%
# IDs originales y nuevos IDs que vamos a usar
old_ids = [17721, 17926, 18263, 19515, 20490, 21371]
new_ids = [26384, 26385, 26386, 26387, 26388, 26389]

# Cambiar solo una ocurrencia de cada ID duplicada por los nuevos IDs especificados
for old_id, new_id in zip(old_ids, new_ids):
    indices = S3_df_BANK_marketing[S3_df_BANK_marketing['id'] == old_id].index
    if len(indices) > 1:  # Asegurarse de que hay duplicados
        S3_df_BANK_marketing.at[indices[1], 'id'] = new_id  # Cambiar solo la segunda ocurrencia

# %% [markdown]
# - Comprobamos resultados

# %%
# Mostrar el DataFrame resultante para verificar los cambios
print(S3_df_BANK_marketing[S3_df_BANK_marketing['id'].isin(old_ids + new_ids)])
# Out:
#           id   age           job  marital  education  is_in_default  balance  \
# 17510  17721  31.0  entrepreneur  married  secondary            0.0       15
# 17715  17926  37.0    management  married   tertiary            0.0     -666
# 18052  18263  41.0    management  married   tertiary            0.0        0
# 19304  19515  57.0       retired  married    primary            0.0     9367
# 20279  20490  44.0    technician  married   tertiary            0.0      964
# 21160  21371  42.0     housemaid  married    primary            1.0       16
# 26177  26385  37.0      services   single  secondary            0.0      278
# 26179  26384  60.0       retired  married    primary            0.0       71
# 26181  26388  47.0   blue-collar  married  secondary            0.0      802
# 26184  26389  40.0        admin.  married  secondary            0.0     1327
# 26185  26386  58.0    unemployed   single   tertiary            0.0     2094
# 26187  26387  42.0   blue-collar  married    primary            0.0     2003
#
#        housing  loan   contact  day month  duration  campaign  pdays  \
# 17510      0.0     1  cellular   29   jan       190         2     -1
# 17715      1.0     0  cellular   18   nov       204         2     -1
# 18052      1.0     0  cellular   18   nov       897         3     -1
# 19304      0.0     0  cellular   11   feb       981         1     90
# 20279      0.0     0  cellular   29   jul       158         2     -1
# 21160      0.0     0   unknown   11   jun        79         1     -1
# 26177      1.0     0   unknown    3   jun      1045         3     -1
# 26179      0.0     0  cellular   10   jul       121         3     -1
# 26181      1.0     1  cellular   12   may       289         2     -1
# 26184      1.0     1   unknown   26   may        76         2     -1
# 26185      0.0     0  cellular    1   jun       161         2     -1
# 26187      1.0     0  cellular   17   apr       177         3     -1
#
#        previous poutcome  deposit
# 17510         0  unknown        0
# 17715         0  unknown        0
# 18052         0  unknown        1
# 19304         6  success        1
# 20279         0  unknown        0
# 21160         0  unknown        0
# 26177         0  unknown        1
# 26179         0  unknown        0
# 26181         0  unknown        1
# 26184         0  unknown        0
# 26185         0  unknown        0
# 26187         0  unknown        0

# %% [markdown]
# ### NULOS

# %% [markdown]
# #### IDENTIFICACIÓN DE NULOS

# %%
S3_df_BANK_marketing.isnull().sum()
# Out:
# id                0
# age              20
# job               0
# marital          13
# education        17
# is_in_default    15
# balance           0
# housing          80
# loan              0
# contact           0
# day               0
# month             0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# deposit           0
# dtype: int64

# %%
S3_df_BANK_marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26179 entries, 0 to 26187
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             26179 non-null  int64
#  1   age            26159 non-null  float64
#  2   job            26179 non-null  object
#  3   marital        26166 non-null  object
#  4   education      26162 non-null  object
#  5   is_in_default  26164 non-null  float64
#  6   balance        26179 non-null  int64
#  7   housing        26099 non-null  float64
#  8   loan           26179 non-null  int64
#  9   contact        26179 non-null  object
#  10  day            26179 non-null  int64
#  11  month          26179 non-null  object
#  12  duration       26179 non-null  int64
#  13  campaign       26179 non-null  int64
#  14  pdays          26179 non-null  int64
#  15  previous       26179 non-null  int64
#  16  poutcome       26179 non-null  object
#  17  deposit        26179 non-null  int64
# dtypes: float64(3), int64(9), object(6)
# memory usage: 4.8+ MB

# %% [markdown]
# #### RESOLUCIÓN DE NULOS

# %% [markdown]
# ##### MARITAL
#   * Propuesta: Usar la moda con respecto a "age"

# %%
nulos_marital = S3_df_BANK_marketing[S3_df_BANK_marketing['marital'].isna()].sort_values('age',ascending=True)
nulos_marital
# Out:
#           id   age          job marital  education  is_in_default  balance  \
# 15513  15514  30.0  blue-collar    None    primary            0.0       35
# 9273    9274  30.0  blue-collar    None    primary            0.0       35
# 4855    4856  34.0   management    None   tertiary            0.0        5
# 13124  13125  34.0   management    None   tertiary            0.0        5
# 25692  25903  34.0   management    None   tertiary            0.0        5
# 1089    1090  53.0   management    None  secondary            0.0     1004
# 24556  24767  53.0   management    None  secondary            0.0     1004
# 6702    6703  60.0       admin.    None    primary            0.0     -444
# 18984  19195  60.0       admin.    None    primary            0.0     -444
# 12584  12585  60.0       admin.    None    primary            0.0     -444
# 25949  26160  60.0       admin.    None    primary            0.0     -444
# 3720    3721  68.0      retired    None  secondary            0.0     4189
# 16990  17201  68.0      retired    None  secondary            0.0     4189
#
#        housing  loan    contact  day month  duration  campaign  pdays  \
# 15513      1.0     0   cellular   11   jul       366         2     -1
# 9273       1.0     0   cellular   11   jul       366         2     -1
# 4855       0.0     0   cellular   18   aug       370         2     -1
# 13124      0.0     0   cellular   18   aug       370         2     -1
# 25692      0.0     0   cellular   18   aug       370         2     -1
# 1089       0.0     1  telephone   22   dec       119         1     -1
# 24556      0.0     1  telephone   22   dec       119         1     -1
# 6702       0.0     1   cellular   16   jul       227         1     -1
# 18984      0.0     1   cellular   16   jul       227         1     -1
# 12584      0.0     1   cellular   16   jul       227         1     -1
# 25949      0.0     1   cellular   16   jul       227         1     -1
# 3720       0.0     0  telephone   14   jul       897         2     -1
# 16990      0.0     0  telephone   14   jul       897         2     -1
#
#        previous poutcome  deposit
# 15513         0  unknown        0
# 9273          0  unknown        0
# 4855          0  unknown        1
# 13124         0  unknown        1
# 25692         0  unknown        1
# 1089          0  unknown        1
# 24556         0  unknown        1
# 6702          0  unknown        0
# 18984         0  unknown        0
# 12584         0  unknown        0
# 25949         0  unknown        0
# 3720          0  unknown        1
# 16990         0  unknown        1

# %%
#DF con los 'ages' en cuestión para descubrir su marital
valores_filtrados = [30, 34, 53, 60, 68] 
df_BANK_marketing_age = S3_df_BANK_marketing[S3_df_BANK_marketing['age'].isin(valores_filtrados)]

# %%
df_BANK_marketing_age.groupby(['age','marital']).agg({'marital': 'count'})
# Out:
#                marital
# age  marital
# 30.0 divorced       50
#      married       347
#      single        669
# 34.0 divorced       70
#      married       641
#      single        374
# 53.0 divorced       80
#      married       342
#      single         37
# 60.0 divorced       85
#      married       318
#      single         10
# 68.0 divorced       11
#      married        32
#      single          8

# %% [markdown]
# ###### RESULTADO MARITAL

# %% [markdown]
# age | marital:
# * 30 -> single
# * 34 -> married
# * 53 -> married
# * 60 -> married
# * 68 -> married

# %%
#Función para asignar el valor a 'marital'
def completar_marital(row):
    if pd.isna(row['marital']):  #Si 'marital' es nulo
        if row['age'] == 30:
            return 'single'
        elif row['age'] == 34:
            return 'married'
        elif row['age'] == 53:
            return 'married'
        elif row['age'] == 60:
            return 'married'
        elif row['age'] == 68:
            return 'married'
    return row['marital']  #Si 'marital' no es nulo, lo dejamos igual

#Ejecuto la función con .apply()
S3_df_BANK_marketing['marital'] = S3_df_BANK_marketing.apply(completar_marital, axis=1)
# Out:
# C:\Users\Federico Labate\AppData\Local\Temp\ipykernel_16684\3117063405.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   S3_df_BANK_marketing['marital'] = S3_df_BANK_marketing.apply(completar_marital, axis=1)

# %%
#Confirmo los cambios con los id afectados
ids_filtrados_marital = [20734, 9274, 4856, 18345, 1090, 6703, 17805, 3721]

df_filtrado_marital = S3_df_BANK_marketing[S3_df_BANK_marketing['id'].isin(ids_filtrados_marital)].sort_values('age',ascending=True)

df_filtrado_marital
# Out:
#           id   age          job   marital  education  is_in_default  balance  \
# 9273    9274  30.0  blue-collar    single    primary            0.0       35
# 18134  18345  33.0  blue-collar   married  secondary            0.0       58
# 4855    4856  34.0   management   married   tertiary            0.0        5
# 20523  20734  36.0  blue-collar   married  secondary            0.0     4438
# 17594  17805  42.0       admin.  divorced  secondary            0.0        0
# 1089    1090  53.0   management   married  secondary            0.0     1004
# 6702    6703  60.0       admin.   married    primary            0.0     -444
# 3720    3721  68.0      retired   married  secondary            0.0     4189
#
#        housing  loan    contact  day month  duration  campaign  pdays  \
# 9273       1.0     0   cellular   11   jul       366         2     -1
# 18134      0.0     0    unknown   16   may       144         2     -1
# 4855       0.0     0   cellular   18   aug       370         2     -1
# 20523      1.0     0    unknown   20   may       446         1     -1
# 17594      1.0     0    unknown    7   may       229         2     -1
# 1089       0.0     1  telephone   22   dec       119         1     -1
# 6702       0.0     1   cellular   16   jul       227         1     -1
# 3720       0.0     0  telephone   14   jul       897         2     -1
#
#        previous poutcome  deposit
# 9273          0  unknown        0
# 18134         0  unknown        0
# 4855          0  unknown        1
# 20523         0  unknown        1
# 17594         0  unknown        0
# 1089          0  unknown        1
# 6702          0  unknown        0
# 3720          0  unknown        1

# %% [markdown]
# ##### AGE
#   * Propuesta: Usar la media de los "marital"

# %%
nulos_age = S3_df_BANK_marketing[S3_df_BANK_marketing['age'].isna()]
nulos_age
# Out:
#           id  age          job   marital  education  is_in_default  balance  \
# 1182    1183  NaN   management   married   tertiary            0.0      309
# 1411    1412  NaN  blue-collar   married    primary            0.0     4979
# 4020    4021  NaN     services    single  secondary            0.0     1934
# 5681    5682  NaN   technician    single   tertiary            0.0      720
# 6764    6765  NaN   technician    single   tertiary            0.0      686
# 8420    8421  NaN  blue-collar   married  secondary            0.0     1782
# 9471    9472  NaN   management   married   tertiary            0.0      552
# 9553    9554  NaN       admin.   married  secondary            0.0     1648
# 9752    9753  NaN     services   married    primary            0.0     2567
# 10679  10680  NaN   technician  divorced   tertiary            0.0        0
# 11625  11626  NaN   technician    single   tertiary            0.0      686
# 11686  11687  NaN       admin.   married  secondary            0.0     1648
# 12339  12340  NaN   management   married   tertiary            0.0      309
# 14396  14397  NaN  blue-collar   married    primary            0.0     4979
# 16034  16035  NaN   management   married   tertiary            0.0      552
# 18209  18420  NaN   management   married   tertiary            0.0      552
# 18456  18667  NaN       admin.   married  secondary            0.0     1648
# 21141  21352  NaN     services    single  secondary            0.0     1934
# 21604  21815  NaN   management   married   tertiary            0.0      552
# 24081  24292  NaN       admin.   married  secondary            0.0     1648
#
#        housing  loan    contact  day month  duration  campaign  pdays  \
# 1182       1.0     0   cellular    5   feb       676         1     -1
# 1411       0.0     0  telephone    6   apr       180         1     -1
# 4020       0.0     0   cellular   29   sep       271         1     -1
# 5681       0.0     0   cellular   12   aug       234         4     -1
# 6764       1.0     0    unknown   30   may        98         2     -1
# 8420       1.0     0    unknown   19   jun       549         1     -1
# 9471       0.0     0   cellular   28   jul       761         8     -1
# 9553       1.0     0   cellular   19   nov       172         3     -1
# 9752       1.0     0   cellular   14   may       109         1    360
# 10679      1.0     0   cellular    2   jun        72         1     -1
# 11625      1.0     0    unknown   30   may        98         2     -1
# 11686      1.0     0   cellular   19   nov       172         3     -1
# 12339      1.0     0   cellular    5   feb       676         1     -1
# 14396      0.0     0  telephone    6   apr       180         1     -1
# 16034      0.0     0   cellular   28   jul       761         8     -1
# 18209      0.0     0   cellular   28   jul       761         8     -1
# 18456      1.0     0   cellular   19   nov       172         3     -1
# 21141      0.0     0   cellular   29   sep       271         1     -1
# 21604      0.0     0   cellular   28   jul       761         8     -1
# 24081      1.0     0   cellular   19   nov       172         3     -1
#
#        previous poutcome  deposit
# 1182          0  unknown        1
# 1411          0  unknown        1
# 4020          0  unknown        1
# 5681          0  unknown        0
# 6764          0  unknown        0
# 8420          0  unknown        0
# 9471          0  unknown        0
# 9553          0  unknown        0
# 9752          2  failure        0
# 10679         0  unknown        0
# 11625         0  unknown        0
# 11686         0  unknown        0
# 12339         0  unknown        1
# 14396         0  unknown        1
# 16034         0  unknown        0
# 18209         0  unknown        0
# 18456         0  unknown        0
# 21141         0  unknown        1
# 21604         0  unknown        0
# 24081         0  unknown        0

# %% [markdown]
# ###### RESULTADO AGE

# %%
# Calcular la media de 'age' para cada categoría en 'marital'
media_por_marital = S3_df_BANK_marketing.groupby('marital')['age'].mean().round(0)
media_por_marital
# Out:
# marital
# divorced    47.0
# married     45.0
# single      33.0
# Name: age, dtype: float64

# %%
#Función para asignar el valor a 'age'
def completar_age(row):
    if pd.isna(row['age']):  #Si 'age' es nulo
        if row['marital'] == 'divorced':
            return 47
        elif row['marital'] == 'married':
            return 45
        elif row['marital'] == 'single':
            return 33
    return row['age']  #Si 'age' no es nulo, lo dejamos igual

#Ejecuto la función con .apply()
S3_df_BANK_marketing['age'] = S3_df_BANK_marketing.apply(completar_age, axis=1)
# Out:
# C:\Users\Federico Labate\AppData\Local\Temp\ipykernel_16684\1446646189.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   S3_df_BANK_marketing['age'] = S3_df_BANK_marketing.apply(completar_age, axis=1)

# %%
#Confirmo los cambios con los id afectados
ids_filtrados_marital = [1183, 1412, 4021, 5682, 6765, 8421, 9472, 9554, 9753, 10680, 11626, 11687, 12340, 14397, 16035,18420,18667,21352,21815,24292]

df_filtrado_marital = S3_df_BANK_marketing[S3_df_BANK_marketing['id'].isin(ids_filtrados_marital)].sort_values('id',ascending=True)

df_filtrado_marital
# Out:
#           id   age          job   marital  education  is_in_default  balance  \
# 1182    1183  45.0   management   married   tertiary            0.0      309
# 1411    1412  45.0  blue-collar   married    primary            0.0     4979
# 4020    4021  33.0     services    single  secondary            0.0     1934
# 5681    5682  33.0   technician    single   tertiary            0.0      720
# 6764    6765  33.0   technician    single   tertiary            0.0      686
# 8420    8421  45.0  blue-collar   married  secondary            0.0     1782
# 9471    9472  45.0   management   married   tertiary            0.0      552
# 9553    9554  45.0       admin.   married  secondary            0.0     1648
# 9752    9753  45.0     services   married    primary            0.0     2567
# 10679  10680  47.0   technician  divorced   tertiary            0.0        0
# 11625  11626  33.0   technician    single   tertiary            0.0      686
# 11686  11687  45.0       admin.   married  secondary            0.0     1648
# 12339  12340  45.0   management   married   tertiary            0.0      309
# 14396  14397  45.0  blue-collar   married    primary            0.0     4979
# 16034  16035  45.0   management   married   tertiary            0.0      552
# 18209  18420  45.0   management   married   tertiary            0.0      552
# 18456  18667  45.0       admin.   married  secondary            0.0     1648
# 21141  21352  33.0     services    single  secondary            0.0     1934
# 21604  21815  45.0   management   married   tertiary            0.0      552
# 24081  24292  45.0       admin.   married  secondary            0.0     1648
#
#        housing  loan    contact  day month  duration  campaign  pdays  \
# 1182       1.0     0   cellular    5   feb       676         1     -1
# 1411       0.0     0  telephone    6   apr       180         1     -1
# 4020       0.0     0   cellular   29   sep       271         1     -1
# 5681       0.0     0   cellular   12   aug       234         4     -1
# 6764       1.0     0    unknown   30   may        98         2     -1
# 8420       1.0     0    unknown   19   jun       549         1     -1
# 9471       0.0     0   cellular   28   jul       761         8     -1
# 9553       1.0     0   cellular   19   nov       172         3     -1
# 9752       1.0     0   cellular   14   may       109         1    360
# 10679      1.0     0   cellular    2   jun        72         1     -1
# 11625      1.0     0    unknown   30   may        98         2     -1
# 11686      1.0     0   cellular   19   nov       172         3     -1
# 12339      1.0     0   cellular    5   feb       676         1     -1
# 14396      0.0     0  telephone    6   apr       180         1     -1
# 16034      0.0     0   cellular   28   jul       761         8     -1
# 18209      0.0     0   cellular   28   jul       761         8     -1
# 18456      1.0     0   cellular   19   nov       172         3     -1
# 21141      0.0     0   cellular   29   sep       271         1     -1
# 21604      0.0     0   cellular   28   jul       761         8     -1
# 24081      1.0     0   cellular   19   nov       172         3     -1
#
#        previous poutcome  deposit
# 1182          0  unknown        1
# 1411          0  unknown        1
# 4020          0  unknown        1
# 5681          0  unknown        0
# 6764          0  unknown        0
# 8420          0  unknown        0
# 9471          0  unknown        0
# 9553          0  unknown        0
# 9752          2  failure        0
# 10679         0  unknown        0
# 11625         0  unknown        0
# 11686         0  unknown        0
# 12339         0  unknown        1
# 14396         0  unknown        1
# 16034         0  unknown        0
# 18209         0  unknown        0
# 18456         0  unknown        0
# 21141         0  unknown        1
# 21604         0  unknown        0
# 24081         0  unknown        0

# %% [markdown]
# ##### EDUCATION
#   *  Propuesta: Usar la moda con respecto a "job"

# %%
nulos_education = S3_df_BANK_marketing[S3_df_BANK_marketing['education'].isna()]
nulos_education
# Out:
#           id   age           job  marital education  is_in_default  balance  \
# 1301    1302  37.0    technician  married      None            0.0      549
# 2944    2945  24.0       student   single      None            0.0      382
# 4738    4739  37.0    management   single      None            0.0      102
# 6820    6821  32.0      services  married      None            0.0     -344
# 7122    7123  57.0  entrepreneur  married      None            0.0      657
# 8593    8594  55.0    management   single      None            0.0      797
# 9407    9408  32.0    technician   single      None            0.0      696
# 13138  13139  32.0    technician   single      None            0.0      696
# 14807  14808  37.0    technician  married      None            0.0      549
# 14915  14916  24.0       student   single      None            0.0      382
# 17436  17647  57.0  entrepreneur  married      None            0.0      657
# 20506  20717  37.0    management   single      None            0.0      102
# 21910  22121  37.0    technician  married      None            0.0      549
# 22638  22849  24.0       student   single      None            0.0      382
# 23431  23642  24.0       student   single      None            0.0      382
# 24472  24683  32.0    technician   single      None            0.0      696
# 26129  26340  37.0    technician  married      None            0.0      549
#
#        housing  loan   contact  day month  duration  campaign  pdays  \
# 1301       0.0     0  cellular    2   mar       239         1     -1
# 2944       0.0     0  cellular   13   nov       256         2     92
# 4738       1.0     0  cellular    6   may       445         1    258
# 6820       0.0     1  cellular    4   feb        44         1     -1
# 7122       0.0     0   unknown   12   jun       344         1     -1
# 8593       0.0     0  cellular   29   jul        24         2     -1
# 9407       0.0     1  cellular   13   aug       101         4    105
# 13138      0.0     1  cellular   13   aug       101         4    105
# 14807      0.0     0  cellular    2   mar       239         1     -1
# 14915      0.0     0  cellular   13   nov       256         2     92
# 17436      0.0     0   unknown   12   jun       344         1     -1
# 20506      1.0     0  cellular    6   may       445         1    258
# 21910      0.0     0  cellular    2   mar       239         1     -1
# 22638      0.0     0  cellular   13   nov       256         2     92
# 23431      0.0     0  cellular   13   nov       256         2     92
# 24472      0.0     1  cellular   13   aug       101         4    105
# 26129      0.0     0  cellular    2   mar       239         1     -1
#
#        previous poutcome  deposit
# 1301          0  unknown        1
# 2944          3  failure        1
# 4738          2  failure        1
# 6820          0  unknown        0
# 7122          0  unknown        0
# 8593          0  unknown        0
# 9407          4  failure        0
# 13138         4  failure        0
# 14807         0  unknown        1
# 14915         3  failure        1
# 17436         0  unknown        0
# 20506         2  failure        1
# 21910         0  unknown        1
# 22638         3  failure        1
# 23431         3  failure        1
# 24472         4  failure        0
# 26129         0  unknown        1

# %%
#DF con los 'job' en cuestión para descubrir su education
valores_filtrados = ['technician', 'student', 'management', 'services', 'entrepreneur'] 
df_BANK_marketing_job = S3_df_BANK_marketing[S3_df_BANK_marketing['job'].isin(valores_filtrados)]

# %%
df_BANK_marketing_job.groupby(['job','education']).agg({'id': 'count'})
# Out:
#                           id
# job          education
# entrepreneur primary     104
#              secondary   348
#              tertiary    289
#              unknown      24
# management   primary     137
#              secondary   538
#              tertiary   5117
#              unknown     196
# services     primary     195
#              secondary  1782
#              tertiary    122
#              unknown     106
# student      primary      52
#              secondary   429
#              tertiary    204
#              unknown     150
# technician   primary      98
#              secondary  2801
#              tertiary   1230
#              unknown     119

# %% [markdown]
# ###### RESULTADO EDUCATION

# %% [markdown]
# job | education:
# * entrepreneur -> secondary
# * management -> tertiary
# * services -> secondary
# * student -> secondary
# * technician -> secondary

# %%
#Función para asignar el valor a 'education'
def completar_education(row):
    if pd.isna(row['education']):  #Si 'job' es nulo
        if row['job'] == 'entrepreneur':
            return 'secondary'
        elif row['job'] == 'management':
            return 'tertiary'
        elif row['job'] == 'services':
            return 'secondary'
        elif row['job'] == 'student':
            return 'secondary'
        elif row['job'] == 'technician':
            return 'secondary'        
    return row['education']  #Si 'education' no es nulo, lo dejamos igual

#Ejecuto la función con .apply()
S3_df_BANK_marketing['education'] = S3_df_BANK_marketing.apply(completar_education, axis=1)
# Out:
# C:\Users\Federico Labate\AppData\Local\Temp\ipykernel_16684\3726271286.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   S3_df_BANK_marketing['education'] = S3_df_BANK_marketing.apply(completar_education, axis=1)

# %%
#Confirmo los cambios con los id afectados
ids_filtrados_education = [1302, 2945, 4739, 6821, 7123, 8594, 9408, 13139, 14808, 14916,17647,20717,22121,22849,23642,24683,26340]

ids_filtrados_education = S3_df_BANK_marketing[S3_df_BANK_marketing['id'].isin(ids_filtrados_education)].sort_values('id',ascending=True)

ids_filtrados_education
# Out:
#           id   age           job  marital  education  is_in_default  balance  \
# 1301    1302  37.0    technician  married  secondary            0.0      549
# 2944    2945  24.0       student   single  secondary            0.0      382
# 4738    4739  37.0    management   single   tertiary            0.0      102
# 6820    6821  32.0      services  married  secondary            0.0     -344
# 7122    7123  57.0  entrepreneur  married  secondary            0.0      657
# 8593    8594  55.0    management   single   tertiary            0.0      797
# 9407    9408  32.0    technician   single  secondary            0.0      696
# 13138  13139  32.0    technician   single  secondary            0.0      696
# 14807  14808  37.0    technician  married  secondary            0.0      549
# 14915  14916  24.0       student   single  secondary            0.0      382
# 17436  17647  57.0  entrepreneur  married  secondary            0.0      657
# 20506  20717  37.0    management   single   tertiary            0.0      102
# 21910  22121  37.0    technician  married  secondary            0.0      549
# 22638  22849  24.0       student   single  secondary            0.0      382
# 23431  23642  24.0       student   single  secondary            0.0      382
# 24472  24683  32.0    technician   single  secondary            0.0      696
# 26129  26340  37.0    technician  married  secondary            0.0      549
#
#        housing  loan   contact  day month  duration  campaign  pdays  \
# 1301       0.0     0  cellular    2   mar       239         1     -1
# 2944       0.0     0  cellular   13   nov       256         2     92
# 4738       1.0     0  cellular    6   may       445         1    258
# 6820       0.0     1  cellular    4   feb        44         1     -1
# 7122       0.0     0   unknown   12   jun       344         1     -1
# 8593       0.0     0  cellular   29   jul        24         2     -1
# 9407       0.0     1  cellular   13   aug       101         4    105
# 13138      0.0     1  cellular   13   aug       101         4    105
# 14807      0.0     0  cellular    2   mar       239         1     -1
# 14915      0.0     0  cellular   13   nov       256         2     92
# 17436      0.0     0   unknown   12   jun       344         1     -1
# 20506      1.0     0  cellular    6   may       445         1    258
# 21910      0.0     0  cellular    2   mar       239         1     -1
# 22638      0.0     0  cellular   13   nov       256         2     92
# 23431      0.0     0  cellular   13   nov       256         2     92
# 24472      0.0     1  cellular   13   aug       101         4    105
# 26129      0.0     0  cellular    2   mar       239         1     -1
#
#        previous poutcome  deposit
# 1301          0  unknown        1
# 2944          3  failure        1
# 4738          2  failure        1
# 6820          0  unknown        0
# 7122          0  unknown        0
# 8593          0  unknown        0
# 9407          4  failure        0
# 13138         4  failure        0
# 14807         0  unknown        1
# 14915         3  failure        1
# 17436         0  unknown        0
# 20506         2  failure        1
# 21910         0  unknown        1
# 22638         3  failure        1
# 23431         3  failure        1
# 24472         4  failure        0
# 26129         0  unknown        1

# %% [markdown]
# ##### HOUSING

# %%
nulos_housing = S3_df_BANK_marketing[S3_df_BANK_marketing['housing'].isna()].sort_values('id',ascending=True)
nulos_housing
# Out:
#           id   age            job   marital  education  is_in_default  \
# 189      190  32.0       services   married  secondary            0.0
# 312      313  39.0    blue-collar   married    primary            0.0
# 1250    1251  47.0   entrepreneur   married   tertiary            0.0
# 1528    1529  38.0     management   married   tertiary            0.0
# 1785    1786  29.0     management    single   tertiary            0.0
# ...      ...   ...            ...       ...        ...            ...
# 21835  22046  47.0     management   married    unknown            0.0
# 23031  23242  34.0       services  divorced  secondary            0.0
# 24500  24711  26.0  self-employed   married  secondary            0.0
# 25360  25571  30.0     management    single   tertiary            0.0
# 25854  26065  42.0     management   married   tertiary            0.0
#
#        balance  housing  loan   contact  day month  duration  campaign  pdays  \
# 189        -34      NaN     0   unknown   30   may      1236         2     -1
# 312       2303      NaN     0   unknown   17   jun       775         3     -1
# 1250         0      NaN     0  cellular   16   feb       261         2     -1
# 1528       165      NaN     0  cellular   17   apr       526         1    260
# 1785      9407      NaN     0  cellular    4   may       267         6     -1
# ...        ...      ...   ...       ...  ...   ...       ...       ...    ...
# 21835     1128      NaN     0  cellular   28   jan        65         2     -1
# 23031       89      NaN     0  cellular   15   may      1871         4     -1
# 24500      492      NaN     1  cellular   15   may       439         4     -1
# 25360     1466      NaN     0  cellular   12   aug       111         4     -1
# 25854      372      NaN     0  cellular    4   aug       153         3      1
#
#        previous poutcome  deposit
# 189           0  unknown        1
# 312           0  unknown        1
# 1250          0  unknown        1
# 1528          2    other        1
# 1785          0  unknown        1
# ...         ...      ...      ...
# 21835         0  unknown        0
# 23031         0  unknown        1
# 24500         0  unknown        0
# 25360         0  unknown        0
# 25854         2  success        1
#
# [80 rows x 18 columns]

# %% [markdown]
# Normalizamos la variable balance para poder trabajarla seguidamente en una prueba T

# %%
from sklearn.preprocessing import StandardScaler
from scipy.stats import ttest_ind

# Crear un objeto StandardScaler
scaler = StandardScaler()

# Normalizar la columna balance
S3_df_BANK_marketing['balance_normalizado'] = scaler.fit_transform(S3_df_BANK_marketing[['balance']])

# Comprobar los primeros valores para verificar la normalización
print(S3_df_BANK_marketing[['balance', 'balance_normalizado']].head())
# Out:
#    balance  balance_normalizado
# 0     2343             0.251390
# 1     2343             0.251390
# 2       45            -0.446981
# 3     1270            -0.074698
# 4     2476             0.291810
# C:\Users\Federico Labate\AppData\Local\Temp\ipykernel_16684\4056848965.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   S3_df_BANK_marketing['balance_normalizado'] = scaler.fit_transform(S3_df_BANK_marketing[['balance']])

# %% [markdown]
# Realizamos la prueba T para comprobar la relación entre variables

# %%
# Dividir los datos según 'housing'
grupo_yes = S3_df_BANK_marketing[S3_df_BANK_marketing['housing'] == 1]['balance_normalizado']
grupo_no = S3_df_BANK_marketing[S3_df_BANK_marketing['housing'] == 0]['balance_normalizado']

# Realizar la prueba T
from scipy.stats import ttest_ind
stat, p_value = ttest_ind(grupo_yes, grupo_no, equal_var=False)


print(f"Estadístico T: {stat}")
print(f"P-valor: {p_value}")
if p_value < 0.05:
    print("Hay una diferencia significativa en los balances normalizados entre los grupos de housing.")
else:
    print("No hay evidencia de diferencias significativas entre los grupos de housing.")
# Out:
# Estadístico T: -12.726073955491447
# P-valor: 5.588052589830387e-37
# Hay una diferencia significativa en los balances normalizados entre los grupos de housing.

# %% [markdown]
# Vamos a realizar los quartiles de balance para distribuirlos por categroias

# %%
def quartiles(qua):
    # calculamos los rangos de los 3 quartiles
    q1 = qua.quantile(0.25)
    q2 = qua.quantile(0.50) 
    q3 = qua.quantile(0.75)

    iqr = q3 - q1 #calculamos el IQR interquartilic range

    # esto sirve para ver el quartil minimo y el quartil maximo
    min_q = q1 - 1.5*iqr
    max_q = q3 + 1.5*iqr
    
    return q1, q2, q3, min_q, max_q

q1, q2, q3, min_q, max_q = quartiles(S3_df_BANK_marketing['balance'])

print(f"Q1 (Primer cuartil): {q1}")
print(f"Q2 (Mediana): {q2}")
print(f"Q3 (Tercer cuartil): {q3}")
print(f"Mínimo (Outlier mínimo): {min_q}")
print(f"Máximo (Outlier máximo): {max_q}")
# Out:
# Q1 (Primer cuartil): 121.0
# Q2 (Mediana): 544.0
# Q3 (Tercer cuartil): 1689.0
# Mínimo (Outlier mínimo): -2231.0
# Máximo (Outlier máximo): 4041.0

# %%
def rango_balance(balance):
    if balance < min_q:
        return "Saldo Muy Bajo"
    elif balance < q1:
        return "Saldo Bajo"
    elif balance < q2:
        return "Saldo Medio"
    elif balance < q3:
        return "Saldo Medio Alto"
    elif balance <= max_q:  # Incluye el límite máximo
        return "Saldo Alto"
    else:  # Todo lo que sea mayor a max_q
        return "Saldo Muy Alto"

S3_df_BANK_marketing['estado_balance'] = S3_df_BANK_marketing['balance'].apply(rango_balance)
S3_df_BANK_marketing.head()
# Out:
# C:\Users\Federico Labate\AppData\Local\Temp\ipykernel_16684\1209974096.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   S3_df_BANK_marketing['estado_balance'] = S3_df_BANK_marketing['balance'].apply(rango_balance)
#    id   age         job  marital  education  is_in_default  balance  housing  \
# 0   1  59.0      admin.  married  secondary            0.0     2343      1.0
# 1   2  59.0      admin.  married  secondary            0.0     2343      1.0
# 2   3  56.0      admin.  married  secondary            0.0       45      0.0
# 3   4  41.0  technician  married  secondary            0.0     1270      1.0
# 4   5  55.0    services  married  secondary            0.0     2476      1.0
#
#    loan  contact  day month  duration  campaign  pdays  previous poutcome  \
# 0     0  unknown    5   may      1042         1     -1         0  unknown
# 1     0  unknown    5   may      1042         1     -1         0  unknown
# 2     0  unknown    5   may      1467         1     -1         0  unknown
# 3     0  unknown    5   may      1389         1     -1         0  unknown
# 4     0  unknown    5   may       579         1     -1         0  unknown
#
#    deposit  balance_normalizado    estado_balance
# 0        1             0.251390        Saldo Alto
# 1        1             0.251390        Saldo Alto
# 2        1            -0.446981        Saldo Bajo
# 3        1            -0.074698  Saldo Medio Alto
# 4        1             0.291810        Saldo Alto

# %%
# Crear tabla resumen de frecuencias de 'housing' por 'estado_balance'
tabla_resumen = (
    S3_df_BANK_marketing[S3_df_BANK_marketing['housing'].notnull()]  # Solo los valores no nulos de housing
    .groupby(['estado_balance', 'housing'])
    .size()  # Contamos las ocurrencias
    .unstack(fill_value=0)  # Unstack para crear una tabla con las columnas de housing
)

tabla_resumen.columns = ['Housing = 0', 'Housing = 1'] #nombre de las columnas
# Calcular porcentajes
tabla_resumen['Housing = 0 (%)'] = (tabla_resumen['Housing = 0'] / (tabla_resumen['Housing = 0'] + tabla_resumen['Housing = 1'])) * 100
tabla_resumen['Housing = 1 (%)'] = (tabla_resumen['Housing = 1'] / (tabla_resumen['Housing = 0'] + tabla_resumen['Housing = 1'])) * 100
print(tabla_resumen)
# Out:
#                   Housing = 0  Housing = 1  Housing = 0 (%)  Housing = 1 (%)
# estado_balance
# Saldo Alto               2490         1583        61.134299        38.865701
# Saldo Bajo               3051         3450        46.931241        53.068759
# Saldo Medio              3364         3166        51.516080        48.483920
# Saldo Medio Alto         3407         3124        52.166590        47.833410
# Saldo Muy Alto           1469          987        59.812704        40.187296
# Saldo Muy Bajo              1            7        12.500000        87.500000

# %% [markdown]
# Con los resultados, se decide imputar en los Nulos de 'Housing' lo siguientes valores según su 'Estado_Balance'
#
# * Saldo Muy Bajo -> 1
# * Saldo Bajo -> 1
# * Saldo Medio -> 0
# * Saldo Medio Alto -> 0
# * Saldo Alto -> 0
# * Saldo Muy Alto -> 0

# %% [markdown]
# ###### RESULTADO HOUSING

# %%
# Función para asignar el valor de 'housing' según 'estado_balance'
def completar_housing(row):
    if pd.isna(row['housing']):  # Si 'housing' es nulo
        if row['estado_balance'] == 'Saldo Muy Bajo':
            return 1
        elif row['estado_balance'] == 'Saldo Bajo':
            return 1
        elif row['estado_balance'] == 'Saldo Medio':
            return 0
        elif row['estado_balance'] == 'Saldo Medio Alto':
            return 0
        elif row['estado_balance'] == 'Saldo Alto':
            return 0
        elif row['estado_balance'] == 'Saldo Muy Alto':
            return 0
    return row['housing']  # Si 'housing' no es nulo, lo dejamos igual

# Ejecutar la función con .apply()
S3_df_BANK_marketing['housing'] = S3_df_BANK_marketing.apply(completar_housing, axis=1)
S3_df_BANK_marketing['housing'] = S3_df_BANK_marketing['housing'].astype(int)#cambiamos la columna de float a int
# Out:
# C:\Users\Federico Labate\AppData\Local\Temp\ipykernel_16684\1499200013.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   S3_df_BANK_marketing['housing'] = S3_df_BANK_marketing.apply(completar_housing, axis=1)
# C:\Users\Federico Labate\AppData\Local\Temp\ipykernel_16684\1499200013.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   S3_df_BANK_marketing['housing'] = S3_df_BANK_marketing['housing'].astype(int)#cambiamos la columna de float a int

# %%
#Confirmo los cambios con algunos ids afectados
ids_filtrados_housing = [190,313,1529,2047,2276,2668,3245,4269,5093,6431,6721,8291,9769,10663,10818,16754,18673,19402, 20074,20514]

df_filtrado_housing = S3_df_BANK_marketing[S3_df_BANK_marketing['id'].isin(ids_filtrados_housing)].sort_values('id',ascending=True)
df_filtrado_housing
# Out:
#           id   age            job   marital  education  is_in_default  \
# 189      190  32.0       services   married  secondary            0.0
# 312      313  39.0    blue-collar   married    primary            0.0
# 1528    1529  38.0     management   married   tertiary            0.0
# 2046    2047  34.0       services  divorced  secondary            0.0
# 2275    2276  40.0         admin.    single  secondary            0.0
# 2667    2668  70.0        retired   married    primary            0.0
# 3244    3245  52.0       services   married  secondary            0.0
# 4268    4269  34.0     technician   married  secondary            0.0
# 5092    5093  42.0     management   married   tertiary            0.0
# 6430    6431  60.0    blue-collar   married  secondary            0.0
# 6720    6721  57.0   entrepreneur   married  secondary            1.0
# 8290    8291  26.0  self-employed   married  secondary            0.0
# 9768    9769  60.0        retired  divorced    primary            0.0
# 10662  10663  55.0    blue-collar  divorced    unknown            0.0
# 10817  10818  47.0     management   married    unknown            0.0
# 16543  16754  31.0  self-employed    single  secondary            0.0
# 18462  18673  58.0   entrepreneur   married  secondary            0.0
# 19191  19402  34.0       services   married  secondary            0.0
# 19863  20074  25.0    blue-collar    single    primary            0.0
# 20303  20514  37.0         admin.   married  secondary            0.0
#
#        balance  housing  loan   contact  day month  duration  campaign  pdays  \
# 189        -34        1     0   unknown   30   may      1236         2     -1
# 312       2303        0     0   unknown   17   jun       775         3     -1
# 1528       165        0     0  cellular   17   apr       526         1    260
# 2046        89        1     0  cellular   15   may      1871         4     -1
# 2275       985        0     0  cellular    4   jun       592         3     50
# 2667      6538        0     0  cellular    9   sep       394         1     -1
# 3244       961        0     1  cellular   18   feb       222         1    553
# 4268         1        1     0  cellular   28   aug       535         2     -1
# 5092       372        0     0  cellular    4   aug       153         3      1
# 6430         0        1     1   unknown    5   jun       124         1     -1
# 6720      -525        1     1  cellular   25   jul       337         1     -1
# 8290       492        0     1  cellular   15   may       439         4     -1
# 9768       -79        1     1  cellular   29   jan       192         1     -1
# 10662      103        1     0  cellular   21   jul       769         3     -1
# 10817     1128        0     0  cellular   28   jan        65         2     -1
# 16543      762        0     0  cellular   11   aug       312         3     -1
# 18462      496        0     0  cellular   22   apr       132         1     -1
# 19191     -315        1     0   unknown    8   may        56         2     -1
# 19863       52        1     0   unknown   24   jun       528         2     -1
# 20303     1396        1     0  cellular   22   jul       199         2     -1
#
#        previous poutcome  deposit  balance_normalizado    estado_balance
# 189           0  unknown        1            -0.470989        Saldo Bajo
# 312           0  unknown        1             0.239234        Saldo Alto
# 1528          2    other        1            -0.410512       Saldo Medio
# 2046          0  unknown        1            -0.433609        Saldo Bajo
# 2275          8  failure        1            -0.161311  Saldo Medio Alto
# 2667          0  unknown        1             1.526267    Saldo Muy Alto
# 3244          4  failure        1            -0.168605  Saldo Medio Alto
# 4268          0  unknown        1            -0.460352        Saldo Bajo
# 5092          2  success        1            -0.347604       Saldo Medio
# 6430          0  unknown        0            -0.460656        Saldo Bajo
# 6720          0  unknown        0            -0.620206        Saldo Bajo
# 8290          0  unknown        0            -0.311136       Saldo Medio
# 9768          0  unknown        0            -0.484665        Saldo Bajo
# 10662         0  unknown        0            -0.429354        Saldo Bajo
# 10817         0  unknown        0            -0.117853  Saldo Medio Alto
# 16543         0  unknown        0            -0.229082  Saldo Medio Alto
# 18462         0  unknown        1            -0.309920       Saldo Medio
# 19191         0  unknown        0            -0.556386        Saldo Bajo
# 19863         0  unknown        1            -0.444853        Saldo Bajo
# 20303         0  unknown        0            -0.036407  Saldo Medio Alto

# %% [markdown]
# ##### IS IN DEFAULT

# %%
nulos_is_in_default = S3_df_BANK_marketing[S3_df_BANK_marketing['is_in_default'].isna()].sort_values('id',ascending=True)
nulos_is_in_default
# Out:
#           id   age            job   marital  education  is_in_default  \
# 967      968  38.0     technician   married   tertiary            NaN
# 2149    2150  41.0  self-employed    single   tertiary            NaN
# 3180    3181  53.0         admin.   married  secondary            NaN
# 5594    5595  38.0     management   married   tertiary            NaN
# 7608    7609  55.0    blue-collar   married    unknown            NaN
# 16346  16557  37.0     management   married   tertiary            NaN
# 16552  16763  47.0     technician   married   tertiary            NaN
# 17117  17328  37.0         admin.    single  secondary            NaN
# 17318  17529  40.0     management    single  secondary            NaN
# 17900  18111  42.0   entrepreneur   married  secondary            NaN
# 18368  18579  46.0     management  divorced   tertiary            NaN
# 18644  18855  46.0     technician   married   tertiary            NaN
# 19618  19829  31.0     management    single   tertiary            NaN
# 19992  20203  30.0     management   married   tertiary            NaN
# 20407  20618  59.0     management   married    unknown            NaN
#
#        balance  housing  loan   contact  day month  duration  campaign  pdays  \
# 967       3234        0     0  cellular   18   nov       578         2     -1
# 2149      1081        0     0  cellular   27   may       229         3     -1
# 3180     10541        0     0  cellular    9   feb       164         2     92
# 5594      1463        1     0  cellular   25   aug       425         4     -1
# 7608        23        0     0  cellular   30   jan       143         1      2
# 16346      -57        1     0  cellular   31   jul        37        20     -1
# 16552     -813        1     1   unknown   16   jun       179        25     -1
# 17117      810        1     0  cellular    8   apr       376         1    295
# 17318    10378        1     0  cellular   17   nov       523         3     -1
# 17900     1002        0     0   unknown   20   jun       109         3     -1
# 18368      461        0     0  cellular   30   dec       369         2     -1
# 18644     4176        1     0   unknown   12   jun       153         6     -1
# 19618     5691        1     0  cellular   21   jul       357         1     -1
# 19992    10884        0     0  cellular    4   may       333         2     -1
# 20407     3428        1     1  cellular   19   nov       103         1     -1
#
#        previous poutcome  deposit  balance_normalizado    estado_balance
# 967           0  unknown        1             0.522169        Saldo Alto
# 2149          0  unknown        1            -0.132136  Saldo Medio Alto
# 3180          1  success        1             2.742794    Saldo Muy Alto
# 5594          0  unknown        0            -0.016045  Saldo Medio Alto
# 7608          3    other        0            -0.453667        Saldo Bajo
# 16346         0  unknown        0            -0.477979        Saldo Bajo
# 16552         0  unknown        0            -0.707730        Saldo Bajo
# 17117         1  failure        0            -0.214494  Saldo Medio Alto
# 17318         0  unknown        0             2.693258    Saldo Muy Alto
# 17900         0  unknown        0            -0.156145  Saldo Medio Alto
# 18368         0  unknown        1            -0.320557       Saldo Medio
# 18644         0  unknown        0             0.808446    Saldo Muy Alto
# 19618         0  unknown        0             1.268860    Saldo Muy Alto
# 19992         0  unknown        1             2.847033    Saldo Muy Alto
# 20407         0  unknown        0             0.581126        Saldo Alto

# %%
# Dividir los datos según 'housing'
grupo_default_yes = S3_df_BANK_marketing[S3_df_BANK_marketing['is_in_default'] == 1]['balance_normalizado']
grupo_default_no = S3_df_BANK_marketing[S3_df_BANK_marketing['is_in_default'] == 0]['balance_normalizado']

# Realizar la prueba T
from scipy.stats import ttest_ind
stat, p_value = ttest_ind(grupo_default_yes, grupo_default_no, equal_var=False)


print(f"Estadístico T: {stat}")
print(f"P-valor: {p_value}")
if p_value < 0.05:
    print("Hay una diferencia significativa en los balances normalizados entre los grupos de is_in_default.")
else:
    print("No hay evidencia de diferencias significativas entre los grupos de is_in_default.")
# Out:
# Estadístico T: -36.22156585536264
# P-valor: 1.4346325575387535e-160
# Hay una diferencia significativa en los balances normalizados entre los grupos de is_in_default.

# %% [markdown]
# Con el resultado del test vemos que la relacion no es azarosa entre el balance y is_in_default por lo tanto podremos filtrarla como housing, según las categorias de balance.

# %%
# Crear tabla resumen de frecuencias de 'is_in_default' por 'estado_balance'
tabla_resumen_default = (
    S3_df_BANK_marketing[S3_df_BANK_marketing['is_in_default'].notnull()]  # Solo los valores no nulos de is_in_default
    .groupby(['estado_balance', 'is_in_default'])
    .size()  # Contamos las ocurrencias
    .unstack(fill_value=0)  # Unstack para crear una tabla con las columnas de is_in_default
)

# Nombrar las columnas
tabla_resumen_default.columns = ['0', '1'] 

# Calcular porcentajes
tabla_resumen_default['0 (%)'] = (tabla_resumen_default['0'] / (tabla_resumen_default['0'] + tabla_resumen_default['1'])) * 100
tabla_resumen_default['1 (%)'] = (tabla_resumen_default['1'] / (tabla_resumen_default['0'] + tabla_resumen_default['1'])) * 100

print(tabla_resumen_default)
# Out:
#                      0    1      0 (%)      1 (%)
# estado_balance
# Saldo Alto        4079    4  99.902033   0.097967
# Saldo Bajo        6196  329  94.957854   5.042146
# Saldo Medio       6502   44  99.327834   0.672166
# Saldo Medio Alto  6518   27  99.587471   0.412529
# Saldo Muy Alto    2454    3  99.877900   0.122100
# Saldo Muy Bajo       7    1  87.500000  12.500000

# %%
conteo = S3_df_BANK_marketing.groupby('estado_balance')['is_in_default'].value_counts()
conteo
# Out:
# estado_balance    is_in_default
# Saldo Alto        0.0              4079
#                   1.0                 4
# Saldo Bajo        0.0              6196
#                   1.0               329
# Saldo Medio       0.0              6502
#                   1.0                44
# Saldo Medio Alto  0.0              6518
#                   1.0                27
# Saldo Muy Alto    0.0              2454
#                   1.0                 3
# Saldo Muy Bajo    0.0                 7
#                   1.0                 1
# Name: count, dtype: int64

# %% [markdown]
# Con los resultados, se decide imputar en los Nulos de 'is_in_default' lo siguientes valores según su 'Estado_Balance'
#
# * Saldo Muy Bajo -> 0
# * Saldo Bajo -> 0
# * Saldo Medio -> 0
# * Saldo Medio Alto -> 0
# * Saldo Alto -> 0
# * Saldo Muy Alto -> 0

# %%
conteo = S3_df_BANK_marketing.groupby('estado_balance')['is_in_default'].value_counts()
conteo
# Out:
# estado_balance    is_in_default
# Saldo Alto        0.0              4079
#                   1.0                 4
# Saldo Bajo        0.0              6196
#                   1.0               329
# Saldo Medio       0.0              6502
#                   1.0                44
# Saldo Medio Alto  0.0              6518
#                   1.0                27
# Saldo Muy Alto    0.0              2454
#                   1.0                 3
# Saldo Muy Bajo    0.0                 7
#                   1.0                 1
# Name: count, dtype: int64

# %% [markdown]
# ###### RESULTADO IS IN DEFAULT

# %%
# Función para asignar el valor de 'is_in_default' según 'estado_balance'
def completar_housing(row):
    if pd.isna(row['is_in_default']):  # Si 'is_in_default' es nulo
        if row['estado_balance'] == 'Saldo Muy Bajo':
            return 0
        elif row['estado_balance'] == 'Saldo Bajo':
            return 0
        elif row['estado_balance'] == 'Saldo Medio':
            return 0
        elif row['estado_balance'] == 'Saldo Medio Alto':
            return 0
        elif row['estado_balance'] == 'Saldo Alto':
            return 0
        elif row['estado_balance'] == 'Saldo Muy Alto':
            return 0
    return row['is_in_default']  # Si 'is_in_default' no es nulo, lo dejamos igual

# Ejecutar la función con .apply()
S3_df_BANK_marketing['is_in_default'] = S3_df_BANK_marketing.apply(completar_housing, axis=1)
# Out:
# C:\Users\Federico Labate\AppData\Local\Temp\ipykernel_16684\4193531244.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   S3_df_BANK_marketing['is_in_default'] = S3_df_BANK_marketing.apply(completar_housing, axis=1)

# %%
ids_filtrados_default = [968,2150,3181,5595,7609,16557,16763,17328,17529,18111,18579,18855,19829,20203,20618]

ids_filtrados_default = S3_df_BANK_marketing[S3_df_BANK_marketing['id'].isin(ids_filtrados_default)].sort_values('id',ascending=True)
ids_filtrados_default
# Out:
#           id   age            job   marital  education  is_in_default  \
# 967      968  38.0     technician   married   tertiary            0.0
# 2149    2150  41.0  self-employed    single   tertiary            0.0
# 3180    3181  53.0         admin.   married  secondary            0.0
# 5594    5595  38.0     management   married   tertiary            0.0
# 7608    7609  55.0    blue-collar   married    unknown            0.0
# 16346  16557  37.0     management   married   tertiary            0.0
# 16552  16763  47.0     technician   married   tertiary            0.0
# 17117  17328  37.0         admin.    single  secondary            0.0
# 17318  17529  40.0     management    single  secondary            0.0
# 17900  18111  42.0   entrepreneur   married  secondary            0.0
# 18368  18579  46.0     management  divorced   tertiary            0.0
# 18644  18855  46.0     technician   married   tertiary            0.0
# 19618  19829  31.0     management    single   tertiary            0.0
# 19992  20203  30.0     management   married   tertiary            0.0
# 20407  20618  59.0     management   married    unknown            0.0
#
#        balance  housing  loan   contact  day month  duration  campaign  pdays  \
# 967       3234        0     0  cellular   18   nov       578         2     -1
# 2149      1081        0     0  cellular   27   may       229         3     -1
# 3180     10541        0     0  cellular    9   feb       164         2     92
# 5594      1463        1     0  cellular   25   aug       425         4     -1
# 7608        23        0     0  cellular   30   jan       143         1      2
# 16346      -57        1     0  cellular   31   jul        37        20     -1
# 16552     -813        1     1   unknown   16   jun       179        25     -1
# 17117      810        1     0  cellular    8   apr       376         1    295
# 17318    10378        1     0  cellular   17   nov       523         3     -1
# 17900     1002        0     0   unknown   20   jun       109         3     -1
# 18368      461        0     0  cellular   30   dec       369         2     -1
# 18644     4176        1     0   unknown   12   jun       153         6     -1
# 19618     5691        1     0  cellular   21   jul       357         1     -1
# 19992    10884        0     0  cellular    4   may       333         2     -1
# 20407     3428        1     1  cellular   19   nov       103         1     -1
#
#        previous poutcome  deposit  balance_normalizado    estado_balance
# 967           0  unknown        1             0.522169        Saldo Alto
# 2149          0  unknown        1            -0.132136  Saldo Medio Alto
# 3180          1  success        1             2.742794    Saldo Muy Alto
# 5594          0  unknown        0            -0.016045  Saldo Medio Alto
# 7608          3    other        0            -0.453667        Saldo Bajo
# 16346         0  unknown        0            -0.477979        Saldo Bajo
# 16552         0  unknown        0            -0.707730        Saldo Bajo
# 17117         1  failure        0            -0.214494  Saldo Medio Alto
# 17318         0  unknown        0             2.693258    Saldo Muy Alto
# 17900         0  unknown        0            -0.156145  Saldo Medio Alto
# 18368         0  unknown        1            -0.320557       Saldo Medio
# 18644         0  unknown        0             0.808446    Saldo Muy Alto
# 19618         0  unknown        0             1.268860    Saldo Muy Alto
# 19992         0  unknown        1             2.847033    Saldo Muy Alto
# 20407         0  unknown        0             0.581126        Saldo Alto

# %% [markdown]
# #### COMPROBACIÓN NULOS

# %%
S3_df_BANK_marketing.isnull().sum()
# Out:
# id                     0
# age                    0
# job                    0
# marital                0
# education              0
# is_in_default          0
# balance                0
# housing                0
# loan                   0
# contact                0
# day                    0
# month                  0
# duration               0
# campaign               0
# pdays                  0
# previous               0
# poutcome               0
# deposit                0
# balance_normalizado    0
# estado_balance         0
# dtype: int64

# %% [markdown]
# ### EXPORTACIÓN A .CSV

# %%
S3_df_BANK_marketing.to_csv('S3_df_BANK_marketing.csv', index=False)

# %% [markdown]
# ### EXPORTACIÓN A PARQUET

# %%
S3_df_BANK_marketing.to_parquet('S3_df_BANK_marketing.parquet', index=False)

# %% [markdown]
# ## EDA (Exploratory Data Analisis)

# %% [markdown]
# ### ESTRUCTURA DEL DATASET

# %% [markdown]
# #### Número de filas y columnas del dataset

# %%
S3_df_BANK_marketing.shape
# Out:
# (26179, 20)

# %% [markdown]
# #### Tipología de los datos y valores nulos del dataset

# %%
S3_df_BANK_marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26179 entries, 0 to 26187
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   26179 non-null  int64
#  1   age                  26179 non-null  float64
#  2   job                  26179 non-null  object
#  3   marital              26179 non-null  object
#  4   education            26179 non-null  object
#  5   is_in_default        26179 non-null  float64
#  6   balance              26179 non-null  int64
#  7   housing              26179 non-null  int64
#  8   loan                 26179 non-null  int64
#  9   contact              26179 non-null  object
#  10  day                  26179 non-null  int64
#  11  month                26179 non-null  object
#  12  duration             26179 non-null  int64
#  13  campaign             26179 non-null  int64
#  14  pdays                26179 non-null  int64
#  15  previous             26179 non-null  int64
#  16  poutcome             26179 non-null  object
#  17  deposit              26179 non-null  int64
#  18  balance_normalizado  26179 non-null  float64
#  19  estado_balance       26179 non-null  object
# dtypes: float64(3), int64(10), object(7)
# memory usage: 5.2+ MB

# %% [markdown]
# #### Primeras filas del dataset

# %%
S3_df_BANK_marketing.head()
# Out:
#    id   age         job  marital  education  is_in_default  balance  housing  \
# 0   1  59.0      admin.  married  secondary            0.0     2343        1
# 1   2  59.0      admin.  married  secondary            0.0     2343        1
# 2   3  56.0      admin.  married  secondary            0.0       45        0
# 3   4  41.0  technician  married  secondary            0.0     1270        1
# 4   5  55.0    services  married  secondary            0.0     2476        1
#
#    loan  contact  day month  duration  campaign  pdays  previous poutcome  \
# 0     0  unknown    5   may      1042         1     -1         0  unknown
# 1     0  unknown    5   may      1042         1     -1         0  unknown
# 2     0  unknown    5   may      1467         1     -1         0  unknown
# 3     0  unknown    5   may      1389         1     -1         0  unknown
# 4     0  unknown    5   may       579         1     -1         0  unknown
#
#    deposit  balance_normalizado    estado_balance
# 0        1             0.251390        Saldo Alto
# 1        1             0.251390        Saldo Alto
# 2        1            -0.446981        Saldo Bajo
# 3        1            -0.074698  Saldo Medio Alto
# 4        1             0.291810        Saldo Alto

# %% [markdown]
# ### VARIABLES DEL DATASET

# %% [markdown]
# #### Variables numéricas

# %%
S3_df_BANK_marketing.describe().round()
# Out:
#             id      age  is_in_default  balance  housing     loan      day  \
# count  26179.0  26179.0        26179.0  26179.0  26179.0  26179.0  26179.0
# mean   13170.0     41.0            0.0   1516.0      0.0      0.0     16.0
# std     7643.0     12.0            0.0   3291.0      0.0      0.0      8.0
# min        1.0     18.0            0.0  -6847.0      0.0      0.0      1.0
# 25%     6546.0     32.0            0.0    121.0      0.0      0.0      8.0
# 50%    13090.0     39.0            0.0    544.0      0.0      0.0     15.0
# 75%    19844.0     49.0            0.0   1689.0      1.0      0.0     22.0
# max    26389.0     95.0            1.0  81204.0      1.0      1.0     31.0
#
#        duration  campaign    pdays  previous  deposit  balance_normalizado
# count   26179.0   26179.0  26179.0   26179.0  26179.0              26179.0
# mean      371.0       3.0     51.0       1.0      0.0                 -0.0
# std       346.0       3.0    109.0       2.0      0.0                  1.0
# min         2.0       1.0     -1.0       0.0      0.0                 -3.0
# 25%       138.0       1.0     -1.0       0.0      0.0                 -0.0
# 50%       254.0       2.0     -1.0       0.0      0.0                 -0.0
# 75%       492.0       3.0     10.0       1.0      1.0                  0.0
# max      3881.0      63.0    854.0      58.0      1.0                 24.0

# %% [markdown]
# #### Variables categóricas

# %%
categorical_columns = S3_df_BANK_marketing.select_dtypes(include=['object', 'category']).columns
print(categorical_columns)
# Out:
# Index(['job', 'marital', 'education', 'contact', 'month', 'poutcome',
#        'estado_balance'],
#       dtype='object')

# %%
for col in categorical_columns:
    print(f"Variable categórica: {col}")
    print(f"Valores y frecuencias:\n{S3_df_BANK_marketing[col].value_counts()}")
    print("-" * 40)
# Out:
# Variable categórica: job
# Valores y frecuencias:
# job
# management       5991
# blue-collar      4548
# technician       4255
# admin.           3141
# services         2206
# retired          1848
# self-employed     936
# student           839
# unemployed        827
# entrepreneur      767
# housemaid         644
# unknown           177
# Name: count, dtype: int64
# ----------------------------------------
# Variable categórica: marital
# Valores y frecuencias:
# marital
# married     14907
# single       8246
# divorced     3026
# Name: count, dtype: int64
# ----------------------------------------
# Variable categórica: education
# Valores y frecuencias:
# education
# secondary    12849
# tertiary      8654
# primary       3489
# unknown       1187
# Name: count, dtype: int64
# ----------------------------------------
# Variable categórica: contact
# Valores y frecuencias:
# contact
# cellular     18899
# unknown       5502
# telephone     1778
# Name: count, dtype: int64
# ----------------------------------------
# Variable categórica: month
# Valores y frecuencias:
# month
# may    6635
# jul    3606
# aug    3572
# jun    2827
# nov    2170
# apr    2161
# feb    1826
# oct     912
# jan     782
# sep     767
# mar     653
# dec     268
# Name: count, dtype: int64
# ----------------------------------------
# Variable categórica: poutcome
# Valores y frecuencias:
# poutcome
# unknown    19559
# failure     2838
# success     2544
# other       1238
# Name: count, dtype: int64
# ----------------------------------------
# Variable categórica: estado_balance
# Valores y frecuencias:
# estado_balance
# Saldo Medio Alto    6549
# Saldo Medio         6547
# Saldo Bajo          6528
# Saldo Alto          4085
# Saldo Muy Alto      2462
# Saldo Muy Bajo         8
# Name: count, dtype: int64
# ----------------------------------------

# %% [markdown]
# #### Valores nulos

# %%
S3_df_BANK_marketing.isnull().sum()
# Out:
# id                     0
# age                    0
# job                    0
# marital                0
# education              0
# is_in_default          0
# balance                0
# housing                0
# loan                   0
# contact                0
# day                    0
# month                  0
# duration               0
# campaign               0
# pdays                  0
# previous               0
# poutcome               0
# deposit                0
# balance_normalizado    0
# estado_balance         0
# dtype: int64

# %% [markdown]
# #### cambio el nomnbre del dataframe S3_df_BANK_marketing a df_BANK_marketing para poder aprovechar el código.

# %%
df_BANK_marketing = S3_df_BANK_marketing

# %% [markdown]
# ### ANÁLISIS VARIABLES CATEGÓRICAS

# %% [markdown]
# #### Variable job

# %%
plt.figure(figsize=(10, 5))
num_job = sns.countplot(data=df_BANK_marketing, x='job', order=df_BANK_marketing['job'].value_counts().index)
for bar in num_job.containers: # número en las barras
    num_job.bar_label(bar)
plt.title('Distribución de Trabajos')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Variable marital

# %%
plt.figure(figsize=(10, 5))
num_marital = sns.countplot(data=df_BANK_marketing, x='marital', order=df_BANK_marketing['marital'].value_counts().index)
for bar in num_marital.containers: # número en las barras
    num_marital.bar_label(bar)
plt.title('Distribución de Estado Civil')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Variable education

# %%
plt.figure(figsize=(10, 5))
num_education = sns.countplot(data=df_BANK_marketing, x='education', order=df_BANK_marketing['education'].value_counts().index)
for bar in num_education.containers: # número en las barras
    num_education.bar_label(bar)
plt.title('Distribución de Educaión')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Variable contact

# %%
plt.figure(figsize=(10, 5))
num_contact = sns.countplot(data=df_BANK_marketing, x='contact', order=df_BANK_marketing['contact'].value_counts().index)
for bar in num_contact.containers: # número en las barras
    num_contact.bar_label(bar)
plt.title('Distribución de Contacto')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Variable month

# %%
plt.figure(figsize=(10, 5))
num_month = sns.countplot(data=df_BANK_marketing, x='month', order=df_BANK_marketing['month'].value_counts().index)
for bar in num_month.containers: # número en las barras
    num_month.bar_label(bar)
plt.title('Distribución de los meses')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Variable poutcome

# %%
plt.figure(figsize=(10, 5))
num_poutcome = sns.countplot(data=df_BANK_marketing, x='poutcome', order=df_BANK_marketing['poutcome'].value_counts().index)
for bar in num_poutcome.containers: # número en las barras
    num_poutcome.bar_label(bar)
plt.title('Distribución de la última campaña')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### ANÁLISIS VARIABLES NUMÉRICAS

# %% [markdown]
# #### Variable balance

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_BANK_marketing['balance'])
plt.title('Distribución de Balance')
plt.xlabel('balance')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df_BANK_marketing, x='balance')
plt.title('Distribución del Balance')
plt.show()

# %%
sns.scatterplot(x="id", y="balance", data=df_BANK_marketing)
plt.title("Distribución del Balance")
plt.show()

# %%
df_BANK_marketing['balance'].value_counts()
# Out:
# balance
# 0        1819
# 1          88
# 3          83
# 2          78
# 5          74
#          ...
# 9317        1
# 164         1
# 2743        1
# 8585        1
# 20772       1
# Name: count, Length: 3805, dtype: int64

# %% [markdown]
# #### Variable duration

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_BANK_marketing['duration'])
plt.title('Distribución de la duración de las llamadas')
plt.xlabel('duration')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df_BANK_marketing, x='duration')
plt.title('Distribución de Duration')
plt.show()

# %%
sns.scatterplot(x="id", y="duration", data=df_BANK_marketing)
plt.title("Distribución de Duration")
plt.show()

# %%
df_BANK_marketing['duration'].value_counts()
# Out:
# duration
# 97      97
# 119     95
# 101     90
# 193     88
# 173     88
#         ..
# 914      1
# 2087     1
# 468      1
# 818      1
# 1689     1
# Name: count, Length: 1428, dtype: int64

# %% [markdown]
# #### Variable campaign

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_BANK_marketing['campaign'])
plt.title('Distribución de la Campaña')
plt.xlabel('campaign')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df_BANK_marketing, x='campaign')
plt.title('Distribución de Campaign')
plt.show()

# %%
sns.scatterplot(x="id", y="campaign", data=df_BANK_marketing)
plt.title("Distribución de Duration")
plt.show()

# %%
df_BANK_marketing['campaign'].value_counts()
# Out:
# campaign
# 1     11214
# 2      7125
# 3      3109
# 4      1836
# 5       871
# 6       621
# 8       329
# 7       318
# 9       159
# 10      118
# 11       84
# 13       73
# 12       68
# 14       35
# 17       33
# 15       26
# 16       25
# 18       20
# 21       19
# 20       11
# 24       10
# 19        9
# 30        9
# 26        8
# 22        7
# 25        7
# 23        6
# 29        5
# 43        5
# 63        4
# 33        4
# 32        3
# 28        3
# 41        2
# 31        2
# 27        1
# Name: count, dtype: int64

# %% [markdown]
# #### Variable age

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_BANK_marketing['age'])
plt.title('Distribución de las edades')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df_BANK_marketing, x='age')
plt.title('Distribución de Age')
plt.show()

# %%
sns.scatterplot(x="id", y="age", data=df_BANK_marketing)
plt.title("Distribución de Age")
plt.show()

# %%
df_BANK_marketing['age'].value_counts()
# Out:
# age
# 31.0    1148
# 32.0    1111
# 34.0    1088
# 35.0    1086
# 30.0    1068
#         ...
# 93.0       5
# 90.0       3
# 92.0       3
# 89.0       3
# 95.0       1
# Name: count, Length: 76, dtype: int64

# %% [markdown]
# #### Variable pdays

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_BANK_marketing['pdays'])
plt.title('Distribución de pdays')
plt.xlabel('pdays')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df_BANK_marketing, x='pdays')
plt.title('Distribución de Pdays')
plt.show()

# %%
sns.scatterplot(x="id", y="pdays", data=df_BANK_marketing)
plt.title("Distribución de Pdays")
plt.show()

# %%
df_BANK_marketing['pdays'].value_counts()
# Out:
# pdays
# -1      19554
#  92       233
#  182      203
#  91       188
#  183      185
#         ...
#  49         1
#  651        1
#  27         1
#  381        1
#  24         1
# Name: count, Length: 472, dtype: int64

# %% [markdown]
# #### Variable previous

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_BANK_marketing['previous'])
plt.title('Distribución de Previous')
plt.xlabel('previous')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df_BANK_marketing, x='previous')
plt.title('Distribución de Previous')
plt.show()

# %%
sns.scatterplot(x="id", y="previous", data=df_BANK_marketing)
plt.title("Distribución de Previous")
plt.show()

# %%
df_BANK_marketing['previous'].value_counts()
# Out:
# previous
# 0     19554
# 1      2067
# 2      1597
# 3      1031
# 4       573
# 5       414
# 6       280
# 7       164
# 8       140
# 9        74
# 10       64
# 11       43
# 12       39
# 13       27
# 17       25
# 15       14
# 14       11
# 19        9
# 16        8
# 58        4
# 30        4
# 22        4
# 20        4
# 28        4
# 27        4
# 29        3
# 41        3
# 18        3
# 26        3
# 23        3
# 40        2
# 37        2
# 55        1
# 21        1
# Name: count, dtype: int64

# %% [markdown]
# ### ANÁLISIS VARIABLES BOOLEANS

# %% [markdown]
# #### Variable is_in_default

# %%
default_counts = df_BANK_marketing['is_in_default'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(default_counts, labels=default_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff', '#99ff99'])
plt.title('Distribución de Clientes en Default')
plt.legend(default_counts.index, title="is_in_default", loc="best")
plt.axis('equal')  
plt.show()

# %% [markdown]
# #### Variable housing

# %%
housing_counts = df_BANK_marketing['housing'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(housing_counts, labels=housing_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff', '#99ff99'])
plt.title('Distribución de Clientes Hipotecados')
plt.legend(default_counts.index, title="hipoteca", loc="best")
plt.axis('equal')  
plt.show()

# %% [markdown]
# #### Variable loan

# %%
loan_counts = df_BANK_marketing['loan'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(loan_counts, labels=loan_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff', '#99ff99'])
plt.title('Distribución de Clientes con Préstamo')
plt.legend(loan_counts.index, title="préstamo", loc="best")
plt.axis('equal')  
plt.show()
