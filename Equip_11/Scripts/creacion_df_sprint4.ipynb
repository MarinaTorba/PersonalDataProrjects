# %%
import numpy as np                  
import pandas as pd                
import matplotlib.pyplot as plt    
import seaborn as sns
import mysql.connector
from mysql.connector import Error
import statsmodels.api as sm

# %% [markdown]
# ### Creacion df a partir de excell

# %%
# Ruta al archivo Excel
ruta_archivo = r"C:\Users\santy\Desktop\Tablas_EAL_2023 pruebas.xlsx"

# Leer las hojas especificando desde qué fila empieza cada tabla
df_eal_20 = pd.read_excel(ruta_archivo, sheet_name='EAL-20', skiprows=7)  # Empieza en fila 8 (índice 7)
df_eal_21 = pd.read_excel(ruta_archivo, sheet_name='EAL-21', skiprows=7)  # Empieza en fila 8 (índice 7)
df_eal_22 = pd.read_excel(ruta_archivo, sheet_name='EAL-22', skiprows=20) # Empieza en fila 21 (índice 20)

# Mostrar las primeras filas de cada DataFrame
print("EAL-20:")
print(df_eal_20.head(15))

print("\nEAL-21:")
print(df_eal_21.head(15))

print("\nEAL-22:")
print(df_eal_22.head(15))
# Out:
# EAL-20:
#                                                                                                           Unnamed: 0  \
# 0                                                                                                       De dirección
# 1                                                                                               De trabajo en equipo
# 2                                                                           De atención al público/ trato a clientes
# 3                                                                                         Administrativas de oficina
# 4                                                                         Técnicas específicas del puesto de trabajo
# 5   De resolución de problemas (localización de problemas o fallos, análisis de sus causas y búsqueda de soluciones)
# 6                                                                                             En lenguas extranjeras
# 7                                                                        Generales de tecnologías de la información
# 8                                                                    Profesionales de tecnologías de la información
# 9                                                                 Básicas de cálculo y/o comunicación oral o escrita
# 10                                                                                                            Otras
# 11                                                                                                               NaN
# 12                                                  (1) Una empresa puede haber señalado de una a tres competencias.
#
#         TOTAL  DE 5 A 9 TRABAJADORES  DE 10 A 49 TRABAJADORES  \
# 0   11.720302              10.023980                12.073995
# 1   25.101616              28.781610                21.260503
# 2   21.546538              22.843817                20.619421
# 3   15.404153              15.530493                15.496009
# 4   41.047326              36.335608                44.172620
# 5   12.247244              13.544494                10.522822
# 6    8.198405               5.161313                 8.189949
# 7   12.089240              11.988897                11.151676
# 8    6.125399               6.826706                 5.137387
# 9    1.914212               2.087012                 1.688298
# 10  18.897610              19.451545                18.852516
# 11        NaN                    NaN                      NaN
# 12        NaN                    NaN                      NaN
#
#     DE 50 A 249 TRABAJADORES  DE 250 A 499 TRABAJADORES  \
# 0                  16.862630                  19.844835
# 1                  25.132275                  28.460596
# 2                  19.238683                  20.049000
# 3                  14.662943                  14.250715
# 4                  48.334313                  45.773785
# 5                  14.124045                  13.719886
# 6                  20.649618                  29.236423
# 7                  15.902410                  19.926501
# 8                   7.084068                   8.697428
# 9                   1.768568                   4.001633
# 10                 17.215364                  15.067374
# 11                       NaN                        NaN
# 12                       NaN                        NaN
#
#     MÁS DE 499 TRABAJADORES
# 0                 25.893769
# 1                 31.205312
# 2                 26.251277
# 3                 11.848825
# 4                 50.408580
# 5                 16.241062
# 6                 29.162411
# 7                 23.237998
# 8                  9.856997
# 9                  3.983657
# 10                11.644535
# 11                      NaN
# 12                      NaN
#
# EAL-21:
#                                                                                                           Unnamed: 0  \
# 0                                                                                                       De dirección
# 1                                                                                               De trabajo en equipo
# 2                                                                           De atención al público/ trato a clientes
# 3                                                                                         Administrativas de oficina
# 4                                                                         Técnicas específicas del puesto de trabajo
# 5   De resolución de problemas (localización de problemas o fallos, análisis de sus causas y búsqueda de soluciones)
# 6                                                                                             En lenguas extranjeras
# 7                                                                        Generales de tecnologías de la información
# 8                                                                    Profesionales de tecnologías de la información
# 9                                                                 Básicas de cálculo y/o comunicación oral o escrita
# 10                                                                                                            Otras
# 11                                                                                                               NaN
# 12                                                  (1) Una empresa puede haber señalado de una a tres competencias.
#
#         TOTAL  INDUSTRIA  CONSTRUCCIÓN  SERVICIOS
# 0   11.720302  10.913108     13.238076  11.605946
# 1   25.101616  19.033095     21.187135  27.323574
# 2   21.546538   9.733897      5.017931  27.663706
# 3   15.404153  14.693309     11.117386  16.434234
# 4   41.047326  56.887939     60.449552  33.401095
# 5   12.089240  10.387146      5.224070  13.872169
# 6    8.198405   9.109467      2.535792   9.121675
# 7   12.247244  11.383832     10.657103  12.771708
# 8    6.125399   4.063596      2.134809   7.415336
# 9    1.914212   1.191220      1.050462   2.258273
# 10  18.897610  19.981747     21.480812  18.121834
# 11        NaN        NaN           NaN        NaN
# 12        NaN        NaN           NaN        NaN
#
# EAL-22:
#                                                                                                           Unnamed: 0  \
# 0                                                                                                       De dirección
# 1                                                                                               De trabajo en equipo
# 2                                                                           De atención al público/ trato a clientes
# 3                                                                                         Administrativas de oficina
# 4                                                                         Técnicas específicas del puesto de trabajo
# 5   De resolución de problemas (localización de problemas o fallos, análisis de sus causas y búsqueda de soluciones)
# 6                                                                                             En lenguas extranjeras
# 7                                                                        Generales de tecnologías de la información
# 8                                                                    Profesionales de tecnologías de la información
# 9                                                                 Básicas de cálculo y/o comunicación oral o escrita
# 10                                                                                                            Otras
# 11                                                                                                               NaN
# 12                                                  (1) Una empresa puede haber señalado de una a tres competencias.
#
#      CATALUÑA  COMUNITAT VALENCIANA  EXTREMADURA    GALICIA  \
# 0   11.366823              9.999650    11.690821  12.402006
# 1   26.903407             27.108455    25.241546  18.108623
# 2   20.386868             19.730174    19.371981  17.020976
# 3   17.460612             17.024920    17.318841  15.198813
# 4   39.387940             42.399776    45.217391  48.753443
# 5   14.394127             14.532872    16.473430   9.315630
# 6   11.183288              9.464891     4.202899   4.308214
# 7   12.952652             11.974415     7.463768   8.482237
# 8    6.827930              5.854392     4.106280   4.244650
# 9    2.530314              3.638461     3.623188   0.367258
# 10  20.403366             16.626472    17.391304  23.342044
# 11        NaN                   NaN          NaN        NaN
# 12        NaN                   NaN          NaN        NaN
#
#     MADRID (COMUNIDAD DE)  MURCIA (REGIÓN DE)  NAVARRA (COMUNIDAD FORAL DE)  \
# 0               13.636364           12.331839                     11.631288
# 1               25.665061           20.757612                     18.028497
# 2               27.010892           22.563134                     14.539110
# 3               14.620863           16.119896                     14.190172
# 4               36.554776           41.267406                     44.722303
# 5               11.232719           15.069625                     12.619948
# 6               13.890344            5.038943                      8.287293
# 7               18.857352            9.310833                     13.172434
# 8               11.855886            4.000472                      6.949695
# 9                2.704755            2.135945                      0.552486
# 10              15.532049           17.205570                     22.099448
# 11                    NaN                 NaN                           NaN
# 12                    NaN                 NaN                           NaN
#
#     PAÍS VASCO  RIOJA, LA
# 0    13.680059  12.147043
# 1    23.186262  21.630261
# 2    17.804618  19.499201
# 3    11.141237  14.597762
# 4    49.338592  46.190730
# 5    11.461671  11.241343
# 6     8.495604   5.807139
# 7    12.981678   9.270112
# 8     4.527155   4.848162
# 9     0.517624   0.745871
# 10   16.128502  16.515717
# 11         NaN        NaN
# 12         NaN        NaN

# %%
import pandas as pd

# Ruta al archivo Excel
ruta_archivo = r"C:\Users\santy\Desktop\Tablas_EAL_2023 pruebas.xlsx"

# --- Cargar datos ---

# EAL-20: empieza en fila 8 (índice 7)
df_eal_20 = pd.read_excel(ruta_archivo, sheet_name='EAL-20', skiprows=7)
# Renombrar primera columna
df_eal_20.rename(columns={df_eal_20.columns[0]: 'Competencias'}, inplace=True)
# Filtrar y reordenar columnas
df_eal_20 = df_eal_20[['Competencias', 'TOTAL', 'DE 250 A 499 TRABAJADORES']]

# EAL-21: empieza en fila 8 (índice 7)
df_eal_21 = pd.read_excel(ruta_archivo, sheet_name='EAL-21', skiprows=7)
df_eal_21.rename(columns={df_eal_21.columns[0]: 'Competencias'}, inplace=True)
df_eal_21 = df_eal_21[['Competencias', 'SERVICIOS']]

# EAL-22: empieza en fila 21 (índice 20)
df_eal_22 = pd.read_excel(ruta_archivo, sheet_name='EAL-22', skiprows=20)
df_eal_22.rename(columns={df_eal_22.columns[0]: 'Competencias'}, inplace=True)
df_eal_22 = df_eal_22[['Competencias', 'CATALUÑA']]

# --- Mostrar resultados ---
print("EAL-20:")
print(df_eal_20.head(12))

print("\nEAL-21:")
print(df_eal_21.head(12))

print("\nEAL-22:")
print(df_eal_22.head(12))
# Out:
# EAL-20:
#                                                                                                         Competencias  \
# 0                                                                                                       De dirección
# 1                                                                                               De trabajo en equipo
# 2                                                                           De atención al público/ trato a clientes
# 3                                                                                         Administrativas de oficina
# 4                                                                         Técnicas específicas del puesto de trabajo
# 5   De resolución de problemas (localización de problemas o fallos, análisis de sus causas y búsqueda de soluciones)
# 6                                                                                             En lenguas extranjeras
# 7                                                                        Generales de tecnologías de la información
# 8                                                                    Profesionales de tecnologías de la información
# 9                                                                 Básicas de cálculo y/o comunicación oral o escrita
# 10                                                                                                            Otras
# 11                                                                                                               NaN
#
#         TOTAL  DE 250 A 499 TRABAJADORES
# 0   11.720302                  19.844835
# 1   25.101616                  28.460596
# 2   21.546538                  20.049000
# 3   15.404153                  14.250715
# 4   41.047326                  45.773785
# 5   12.247244                  13.719886
# 6    8.198405                  29.236423
# 7   12.089240                  19.926501
# 8    6.125399                   8.697428
# 9    1.914212                   4.001633
# 10  18.897610                  15.067374
# 11        NaN                        NaN
#
# EAL-21:
#                                                                                                         Competencias  \
# 0                                                                                                       De dirección
# 1                                                                                               De trabajo en equipo
# 2                                                                           De atención al público/ trato a clientes
# 3                                                                                         Administrativas de oficina
# 4                                                                         Técnicas específicas del puesto de trabajo
# 5   De resolución de problemas (localización de problemas o fallos, análisis de sus causas y búsqueda de soluciones)
# 6                                                                                             En lenguas extranjeras
# 7                                                                        Generales de tecnologías de la información
# 8                                                                    Profesionales de tecnologías de la información
# 9                                                                 Básicas de cálculo y/o comunicación oral o escrita
# 10                                                                                                            Otras
# 11                                                                                                               NaN
#
#     SERVICIOS
# 0   11.605946
# 1   27.323574
# 2   27.663706
# 3   16.434234
# 4   33.401095
# 5   13.872169
# 6    9.121675
# 7   12.771708
# 8    7.415336
# 9    2.258273
# 10  18.121834
# 11        NaN
#
# EAL-22:
#                                                                                                         Competencias  \
# 0                                                                                                       De dirección
# 1                                                                                               De trabajo en equipo
# 2                                                                           De atención al público/ trato a clientes
# 3                                                                                         Administrativas de oficina
# 4                                                                         Técnicas específicas del puesto de trabajo
# 5   De resolución de problemas (localización de problemas o fallos, análisis de sus causas y búsqueda de soluciones)
# 6                                                                                             En lenguas extranjeras
# 7                                                                        Generales de tecnologías de la información
# 8                                                                    Profesionales de tecnologías de la información
# 9                                                                 Básicas de cálculo y/o comunicación oral o escrita
# 10                                                                                                            Otras
# 11                                                                                                               NaN
#
#      CATALUÑA
# 0   11.366823
# 1   26.903407
# 2   20.386868
# 3   17.460612
# 4   39.387940
# 5   14.394127
# 6   11.183288
# 7   12.952652
# 8    6.827930
# 9    2.530314
# 10  20.403366
# 11        NaN

# %%
import pandas as pd

# Ruta al archivo Excel
ruta_archivo = r"C:\Users\santy\Desktop\Tablas_EAL_2023 pruebas.xlsx"

# --- Cargar y preparar EAL-20 ---
df_eal_20 = pd.read_excel(ruta_archivo, sheet_name='EAL-20', skiprows=7)
df_eal_20.rename(columns={df_eal_20.columns[0]: 'Competencias'}, inplace=True)
df_eal_20 = df_eal_20[['Competencias', 'TOTAL', 'DE 250 A 499 TRABAJADORES']]
df_eal_20.rename(columns={
    'TOTAL': 'total empresas',
    'DE 250 A 499 TRABAJADORES': 'EMPRESAS DE 250 A 499 TRABAJADORES'
}, inplace=True)

# --- Cargar y preparar EAL-21 ---
df_eal_21 = pd.read_excel(ruta_archivo, sheet_name='EAL-21', skiprows=7)
df_eal_21.rename(columns={df_eal_21.columns[0]: 'Competencias'}, inplace=True)
df_eal_21 = df_eal_21[['Competencias', 'SERVICIOS']]
df_eal_21.rename(columns={
    'SERVICIOS': 'EMPRESAS SECTOR SERVICIOS'
}, inplace=True)

# --- Cargar y preparar EAL-22 ---
df_eal_22 = pd.read_excel(ruta_archivo, sheet_name='EAL-22', skiprows=20)
df_eal_22.rename(columns={df_eal_22.columns[0]: 'Competencias'}, inplace=True)
df_eal_22 = df_eal_22[['Competencias', 'CATALUÑA']]
df_eal_22.rename(columns={
    'CATALUÑA': 'EMPRESAS COMUNIDAD CATALUÑA'
}, inplace=True)

# --- Unir los tres DataFrames ---
df_final = df_eal_20.merge(df_eal_21, on='Competencias', how='inner')
df_final = df_final.merge(df_eal_22, on='Competencias', how='inner')

# --- Mostrar resultado ---
print("DataFrame Final:")
print(df_final.head(15))
# Out:
# DataFrame Final:
#                                                                                                         Competencias  \
# 0                                                                                                       De dirección
# 1                                                                                               De trabajo en equipo
# 2                                                                           De atención al público/ trato a clientes
# 3                                                                                         Administrativas de oficina
# 4                                                                         Técnicas específicas del puesto de trabajo
# 5   De resolución de problemas (localización de problemas o fallos, análisis de sus causas y búsqueda de soluciones)
# 6                                                                                             En lenguas extranjeras
# 7                                                                        Generales de tecnologías de la información
# 8                                                                    Profesionales de tecnologías de la información
# 9                                                                 Básicas de cálculo y/o comunicación oral o escrita
# 10                                                                                                            Otras
# 11                                                                                                               NaN
# 12                                                  (1) Una empresa puede haber señalado de una a tres competencias.
#
#     total empresas  EMPRESAS DE 250 A 499 TRABAJADORES  \
# 0        11.720302                           19.844835
# 1        25.101616                           28.460596
# 2        21.546538                           20.049000
# 3        15.404153                           14.250715
# 4        41.047326                           45.773785
# 5        12.247244                           13.719886
# 6         8.198405                           29.236423
# 7        12.089240                           19.926501
# 8         6.125399                            8.697428
# 9         1.914212                            4.001633
# 10       18.897610                           15.067374
# 11             NaN                                 NaN
# 12             NaN                                 NaN
#
#     EMPRESAS SECTOR SERVICIOS  EMPRESAS COMUNIDAD CATALUÑA
# 0                   11.605946                    11.366823
# 1                   27.323574                    26.903407
# 2                   27.663706                    20.386868
# 3                   16.434234                    17.460612
# 4                   33.401095                    39.387940
# 5                   13.872169                    14.394127
# 6                    9.121675                    11.183288
# 7                   12.771708                    12.952652
# 8                    7.415336                     6.827930
# 9                    2.258273                     2.530314
# 10                  18.121834                    20.403366
# 11                        NaN                          NaN
# 12                        NaN                          NaN
